# %%
import pandas as pd
import os
import random

def generate_train_valid_test(dataset_dir,left_prefix,right_prefix):
	df_tableA = pd.read_csv(os.path.join(dataset_dir,'tableA.csv'))
	df_tableB = pd.read_csv(os.path.join(dataset_dir,'tableB.csv'))
	df_train = pd.read_csv(os.path.join(dataset_dir,'train.csv'))
	df_valid = pd.read_csv(os.path.join(dataset_dir,'valid.csv'))
	df_test = pd.read_csv(os.path.join(dataset_dir,'test.csv'))
	left_columns = []
	right_columns = []
	for lcol,rcol in zip(list(df_tableA),list(df_tableB)):
		left_columns.append(left_prefix+lcol)
		right_columns.append(right_prefix+rcol)
	df_tableA.columns = left_columns
	df_tableB.columns = right_columns

	#P sta per parziale
	ptrain=pd.merge(df_train,df_tableA, how='inner')
	pvalid=pd.merge(df_valid,df_tableA,how='inner')
	ptest=pd.merge(df_test,df_tableA,how='inner')
	train=pd.merge(ptrain,df_tableB,how='inner')
	valid=pd.merge(pvalid,df_tableB,how='inner')
	test=pd.merge(ptest,df_tableB,how='inner')

	train_lenght =train.shape[0]
	valid_lenght = valid.shape[0]
	test_lenght = test.shape[0]

	train_ids = random.sample(range(0,train_lenght),train_lenght)
	valid_ids = random.sample(range(train_lenght+1,train_lenght+valid_lenght+1),valid_lenght)
	test_ids = random.sample(range(train_lenght+valid_lenght+2,
		train_lenght+valid_lenght+test_lenght+2),test_lenght)

	train = train.drop(['ltable_id','rtable_id'],axis=1)
	valid = valid.drop(['ltable_id','rtable_id'],axis=1)
	test = test.drop(['ltable_id','rtable_id'],axis=1)

	train['id'] =train_ids
	valid['id'] = valid_ids
	test['id'] = test_ids
	return train,valid,test

# %%
train,valid,test = generate_train_valid_test('Structured/Beer/','ltable_','rtable_')

# %%
train.head()
# Out:
#    label                                   ltable_Beer_Name  \
# 0      0                           C N Red Imperial Red Ale
# 1      0  Mountain Series : Love Rhino ( Imperial Red Ale )
# 2      0                         Arthur 's Imperial Red Ale
# 3      0                          Deranger Imperial Red Ale
# 4      0                  Red Shedman 's Imperial Amber Ale
#
#             ltable_Brew_Factory_Name              ltable_Style ltable_ABV  \
# 0                      Redwood Lodge  American Amber / Red Ale     8.10 %
# 1               Breckenridge Brewery  American Amber / Red Ale     8.90 %
# 2            Otto 's Pub and Brewery  American Amber / Red Ale     6.90 %
# 3  Laurelwood Public House & Brewery  American Amber / Red Ale     8.60 %
# 4               57 Brew Pub & Bistro  American Amber / Red Ale     7.60 %
#
#                     rtable_Beer_Name rtable_Brew_Factory_Name  \
# 0  Kinetic Infrared Imperial Red Ale  Kinetic Brewing Company
# 1  Kinetic Infrared Imperial Red Ale  Kinetic Brewing Company
# 2  Kinetic Infrared Imperial Red Ale  Kinetic Brewing Company
# 3  Kinetic Infrared Imperial Red Ale  Kinetic Brewing Company
# 4  Kinetic Infrared Imperial Red Ale  Kinetic Brewing Company
#
#           rtable_Style rtable_ABV   id
# 0  American Strong Ale     9.30 %   67
# 1  American Strong Ale     9.30 %  146
# 2  American Strong Ale     9.30 %  103
# 3  American Strong Ale     9.30 %   55
# 4  American Strong Ale     9.30 %  124

# %%
test.head()
# Out:
#    label                              ltable_Beer_Name  \
# 0      0          Bulleit Bourbon Barrel Aged G'Knight
# 1      0                Double Dragon Imperial Red Ale
# 2      0  Batch 200 _ `` Olympus Mons Imperial Red Ale
# 3      1                             Honey Basil Amber
# 4      0                       Clifford 's Big Red Ale
#
#      ltable_Brew_Factory_Name              ltable_Style ltable_ABV  \
# 0    Oskar Blues Grill & Brew  American Amber / Red Ale     8.70 %
# 1    Phillips Brewing Company  American Amber / Red Ale     8.20 %
# 2     Due South Brewing Co. .  American Amber / Red Ale     9.20 %
# 3  Rude Hippo Brewing Company  American Amber / Red Ale     7.40 %
# 4        Funky Buddha Brewery  American Amber / Red Ale     9.70 %
#
#                               rtable_Beer_Name   rtable_Brew_Factory_Name  \
# 0  Figure Eight Bourbon Barrel Aged Jumbo Love       Figure Eight Brewing
# 1      Scuttlebutt Mateo Loco Imperial Red Ale  Scuttlebutt Brewing Co. .
# 2      Scuttlebutt Mateo Loco Imperial Red Ale  Scuttlebutt Brewing Co. .
# 3                 Rude Hippo Honey Basil Amber        18th Street Brewery
# 4                     Big Island Red Giant Ale        Big Island Brewhaus
#
#           rtable_Style rtable_ABV   id
# 0          Barley Wine          -  427
# 1  American Strong Ale     7.10 %  419
# 2  American Strong Ale     7.10 %  399
# 3            Amber Ale     7.40 %  365
# 4  American Strong Ale     6.50 %  436
