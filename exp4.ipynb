# %% [markdown]
# ## Experiment 4
# We want to evaluate the effect of converting string to unique ID respect to the Ri values

# %% [markdown]
# ### First train the model with new encoding

# %%
import deepmatcher as dm
from utilities_functions.intermediate_layer_extraction import Hook,return_layer_input_output
import torch
from deepmatcher.data import MatchingIterator

torch.cuda.is_available()
# Out:
# True

# %%
hybrid_model_numericencoding = dm.MatchingModel(attr_summarizer='hybrid')
train,valid,test = dm.data.process('sample_data/itunes-amazon/exp4',train='train_numericencoding.csv',
                                  validation='validation_numericencoding.csv',test='test_numericencoding.csv')

# %%
hybrid_model_numericencoding.load_state('models/hybrid_numericencoding.pth')
hybrid_model_numericencoding.cuda()
# Out:
# MatchingModel(
#   (attr_summarizers): ModuleMap(
#     (Song_Name): Hybrid(
#       (word_contextualizer): RNN(
#         (rnn_groups): ModuleList(
#           (0): GRU(300, 150, batch_first=True, bidirectional=True)
#         )
#         (dropouts): ModuleList(
#           (0): Dropout(p=0)
#         )
#         (bypass_networks): ModuleList(
#           (0): None
#         )
#         (input_dropout): NoMeta(
#           (module): Dropout(p=0)
#         )
#       )
#       (word_comparator): Attention(
#         (alignment_networks): ModuleList(
#           (0): AlignmentNetwork(
#             (transform): Transform(
#               (transforms): ModuleList(
#                 (0): Linear(in_features=300, out_features=300, bias=True)
#                 (1): Linear(in_features=300, out_features=300, bias=True)
#               )
#               (bypass_networks): ModuleList(
#                 (0): Bypass(
#                   (highway_gate): Linear(in_features=300, out_features=300, bias=True)
#                 )
#                 (1): Bypass(
#                   (highway_gate): Linear(in_features=300, out_features=300, bias=True)
#                 )
#               )
#             )
#           )
#         )
#         (value_merge): Merge(
#         )
#         (comparison_merge): Merge(
#         )
#         (comparison_network): Transform(
#           (transforms): ModuleList(
#             (0): Linear(in_features=600, out_features=300, bias=True)
#             (1): Linear(in_features=300, out_features=300, bias=True)
#           )
#           (bypass_networks): ModuleList(
#             (0): Bypass(
#               (highway_gate): Linear(in_features=600, out_features=300, bias=True)
#             )
#             (1): Bypass(
#               (highway_gate): Linear(in_features=300, out_features=300, bias=True)
#             )
#           )
#         )
#         (input_dropout): Dropout(p=0)
#         (transform_dropout): Dropout(p=0)
#         (score_dropout): Dropout(p=0)
#         (softmax): Softmax()
#       )
#       (word_aggregator): AttentionWithRNN(
#         (rnn): RNN(
#           (rnn_groups): ModuleList(
#             (0): GRU(300, 150, batch_first=True, bidirectional=True)
#           )
#           (dropouts): ModuleList(
#             (0): Dropout(p=0)
#           )
#           (bypass_networks): ModuleList(
#             (0): None
#           )
#           (input_dropout): NoMeta(
#             (module): Dropout(p=0)
#           )
#         )
#         (rnn_pool): Pool(
#         )
#         (input_context_comparison_network): Transform(
#           (transforms): ModuleList(
#             (0): Linear(in_features=600, out_features=300, bias=True)
#           )
#           (bypass_networks): ModuleList(
#             (0): Bypass(
#               (highway_gate): Linear(in_features=600, out_features=300, bias=True)
#             )
#           )
#         )
#         (scoring_network): Transform(
#           (transforms): ModuleList(
#             (0): Linear(in_features=300, out_features=1, bias=True)
#           )
#           (bypass_networks): ModuleList(
#             (0): None
#           )
#         )
#         (input_dropout): Dropout(p=0)
#         (transform_dropout): Dropout(p=0)
#         (score_dropout): Dropout(p=0)
#         (softmax): Softmax()
#       )
#     )
#     (Artist_Name): Hybrid(
#       (word_contextualizer): RNN(
#         (rnn_groups): ModuleList(
#           (0): GRU(300, 150, batch_first=True, bidirectional=True)
#         )
#         (dropouts): ModuleList(
#           (0): Dropout(p=0)
#         )
#         (bypass_networks): ModuleList(
#           (0): None
#         )
#         (input_dropout): NoMeta(
#           (module): Dropout(p=0)
#         )
#       )
#       (word_comparator): Attention(
#         (alignment_networks): ModuleList(
#           (0): AlignmentNetwork(
#             (transform): Transform(
#               (transforms): ModuleList(
#                 (0): Linear(in_features=300, out_features=300, bias=True)
#                 (1): Linear(in_features=300, out_features=300, bias=True)
#               )
#               (bypass_networks): ModuleList(
#                 (0): Bypass(
#                   (highway_gate): Linear(in_features=300, out_features=300, bias=True)
#                 )
#                 (1): Bypass(
#                   (highway_gate): Linear(in_features=300, out_features=300, bias=True)
#                 )
#               )
#             )
#           )
#         )
#         (value_merge): Merge(
#         )
#         (comparison_merge): Merge(
#         )
#         (comparison_network): Transform(
#           (transforms): ModuleList(
#             (0): Linear(in_features=600, out_features=300, bias=True)
#             (1): Linear(in_features=300, out_features=300, bias=True)
#           )
#           (bypass_networks): ModuleList(
#             (0): Bypass(
#               (highway_gate): Linear(in_features=600, out_features=300, bias=True)
#             )
#             (1): Bypass(
#               (highway_gate): Linear(in_features=300, out_features=300, bias=True)
#             )
#           )
#         )
#         (input_dropout): Dropout(p=0)
#         (transform_dropout): Dropout(p=0)
#         (score_dropout): Dropout(p=0)
#         (softmax): Softmax()
#       )
#       (word_aggregator): AttentionWithRNN(
#         (rnn): RNN(
#           (rnn_groups): ModuleList(
#             (0): GRU(300, 150, batch_first=True, bidirectional=True)
#           )
#           (dropouts): ModuleList(
#             (0): Dropout(p=0)
#           )
#           (bypass_networks): ModuleList(
#             (0): None
#           )
#           (input_dropout): NoMeta(
#             (module): Dropout(p=0)
#           )
#         )
#         (rnn_pool): Pool(
#         )
#         (input_context_comparison_network): Transform(
#           (transforms): ModuleList(
#             (0): Linear(in_features=600, out_features=300, bias=True)
#           )
#           (bypass_networks): ModuleList(
#             (0): Bypass(
#               (highway_gate): Linear(in_features=600, out_features=300, bias=True)
#             )
#           )
#         )
#         (scoring_network): Transform(
#           (transforms): ModuleList(
#             (0): Linear(in_features=300, out_features=1, bias=True)
#           )
#           (bypass_networks): ModuleList(
#             (0): None
#           )
#         )
#         (input_dropout): Dropout(p=0)
#         (transform_dropout): Dropout(p=0)
#         (score_dropout): Dropout(p=0)
#         (softmax): Softmax()
#       )
#     )
#     (Album_Name): Hybrid(
#       (word_contextualizer): RNN(
#         (rnn_groups): ModuleList(
#           (0): GRU(300, 150, batch_first=True, bidirectional=True)
#         )
#         (dropouts): ModuleList(
#           (0): Dropout(p=0)
#         )
#         (bypass_networks): ModuleList(
#           (0): None
#         )
#         (input_dropout): NoMeta(
#           (module): Dropout(p=0)
#         )
#       )
#       (word_comparator): Attention(
#         (alignment_networks): ModuleList(
#           (0): AlignmentNetwork(
#             (transform): Transform(
#               (transforms): ModuleList(
#                 (0): Linear(in_features=300, out_features=300, bias=True)
#                 (1): Linear(in_features=300, out_features=300, bias=True)
#               )
#               (bypass_networks): ModuleList(
#                 (0): Bypass(
#                   (highway_gate): Linear(in_features=300, out_features=300, bias=True)
#                 )
#                 (1): Bypass(
#                   (highway_gate): Linear(in_features=300, out_features=300, bias=True)
#                 )
#               )
#             )
#           )
#         )
#         (value_merge): Merge(
#         )
#         (comparison_merge): Merge(
#         )
#         (comparison_network): Transform(
#           (transforms): ModuleList(
#             (0): Linear(in_features=600, out_features=300, bias=True)
#             (1): Linear(in_features=300, out_features=300, bias=True)
#           )
#           (bypass_networks): ModuleList(
#             (0): Bypass(
#               (highway_gate): Linear(in_features=600, out_features=300, bias=True)
#             )
#             (1): Bypass(
#               (highway_gate): Linear(in_features=300, out_features=300, bias=True)
#             )
#           )
#         )
#         (input_dropout): Dropout(p=0)
#         (transform_dropout): Dropout(p=0)
#         (score_dropout): Dropout(p=0)
#         (softmax): Softmax()
#       )
#       (word_aggregator): AttentionWithRNN(
#         (rnn): RNN(
#           (rnn_groups): ModuleList(
#             (0): GRU(300, 150, batch_first=True, bidirectional=True)
#           )
#           (dropouts): ModuleList(
#             (0): Dropout(p=0)
#           )
#           (bypass_networks): ModuleList(
#             (0): None
#           )
#           (input_dropout): NoMeta(
#             (module): Dropout(p=0)
#           )
#         )
#         (rnn_pool): Pool(
#         )
#         (input_context_comparison_network): Transform(
#           (transforms): ModuleList(
#             (0): Linear(in_features=600, out_features=300, bias=True)
#           )
#           (bypass_networks): ModuleList(
#             (0): Bypass(
#               (highway_gate): Linear(in_features=600, out_features=300, bias=True)
#             )
#           )
#         )
#         (scoring_network): Transform(
#           (transforms): ModuleList(
#             (0): Linear(in_features=300, out_features=1, bias=True)
#           )
#           (bypass_networks): ModuleList(
#             (0): None
#           )
#         )
#         (input_dropout): Dropout(p=0)
#         (transform_dropout): Dropout(p=0)
#         (score_dropout): Dropout(p=0)
#         (softmax): Softmax()
#       )
#     )
#     (Genre): Hybrid(
#       (word_contextualizer): RNN(
#         (rnn_groups): ModuleList(
#           (0): GRU(300, 150, batch_first=True, bidirectional=True)
#         )
#         (dropouts): ModuleList(
#           (0): Dropout(p=0)
#         )
#         (bypass_networks): ModuleList(
#           (0): None
#         )
#         (input_dropout): NoMeta(
#           (module): Dropout(p=0)
#         )
#       )
#       (word_comparator): Attention(
#         (alignment_networks): ModuleList(
#           (0): AlignmentNetwork(
#             (transform): Transform(
#               (transforms): ModuleList(
#                 (0): Linear(in_features=300, out_features=300, bias=True)
#                 (1): Linear(in_features=300, out_features=300, bias=True)
#               )
#               (bypass_networks): ModuleList(
#                 (0): Bypass(
#                   (highway_gate): Linear(in_features=300, out_features=300, bias=True)
#                 )
#                 (1): Bypass(
#                   (highway_gate): Linear(in_features=300, out_features=300, bias=True)
#                 )
#               )
#             )
#           )
#         )
#         (value_merge): Merge(
#         )
#         (comparison_merge): Merge(
#         )
#         (comparison_network): Transform(
#           (transforms): ModuleList(
#             (0): Linear(in_features=600, out_features=300, bias=True)
#             (1): Linear(in_features=300, out_features=300, bias=True)
#           )
#           (bypass_networks): ModuleList(
#             (0): Bypass(
#               (highway_gate): Linear(in_features=600, out_features=300, bias=True)
#             )
#             (1): Bypass(
#               (highway_gate): Linear(in_features=300, out_features=300, bias=True)
#             )
#           )
#         )
#         (input_dropout): Dropout(p=0)
#         (transform_dropout): Dropout(p=0)
#         (score_dropout): Dropout(p=0)
#         (softmax): Softmax()
#       )
#       (word_aggregator): AttentionWithRNN(
#         (rnn): RNN(
#           (rnn_groups): ModuleList(
#             (0): GRU(300, 150, batch_first=True, bidirectional=True)
#           )
#           (dropouts): ModuleList(
#             (0): Dropout(p=0)
#           )
#           (bypass_networks): ModuleList(
#             (0): None
#           )
#           (input_dropout): NoMeta(
#             (module): Dropout(p=0)
#           )
#         )
#         (rnn_pool): Pool(
#         )
#         (input_context_comparison_network): Transform(
#           (transforms): ModuleList(
#             (0): Linear(in_features=600, out_features=300, bias=True)
#           )
#           (bypass_networks): ModuleList(
#             (0): Bypass(
#               (highway_gate): Linear(in_features=600, out_features=300, bias=True)
#             )
#           )
#         )
#         (scoring_network): Transform(
#           (transforms): ModuleList(
#             (0): Linear(in_features=300, out_features=1, bias=True)
#           )
#           (bypass_networks): ModuleList(
#             (0): None
#           )
#         )
#         (input_dropout): Dropout(p=0)
#         (transform_dropout): Dropout(p=0)
#         (score_dropout): Dropout(p=0)
#         (softmax): Softmax()
#       )
#     )
#     (Price): Hybrid(
#       (word_contextualizer): RNN(
#         (rnn_groups): ModuleList(
#           (0): GRU(300, 150, batch_first=True, bidirectional=True)
#         )
#         (dropouts): ModuleList(
#           (0): Dropout(p=0)
#         )
#         (bypass_networks): ModuleList(
#           (0): None
#         )
#         (input_dropout): NoMeta(
#           (module): Dropout(p=0)
#         )
#       )
#       (word_comparator): Attention(
#         (alignment_networks): ModuleList(
#           (0): AlignmentNetwork(
#             (transform): Transform(
#               (transforms): ModuleList(
#                 (0): Linear(in_features=300, out_features=300, bias=True)
#                 (1): Linear(in_features=300, out_features=300, bias=True)
#               )
#               (bypass_networks): ModuleList(
#                 (0): Bypass(
#                   (highway_gate): Linear(in_features=300, out_features=300, bias=True)
#                 )
#                 (1): Bypass(
#                   (highway_gate): Linear(in_features=300, out_features=300, bias=True)
#                 )
#               )
#             )
#           )
#         )
#         (value_merge): Merge(
#         )
#         (comparison_merge): Merge(
#         )
#         (comparison_network): Transform(
#           (transforms): ModuleList(
#             (0): Linear(in_features=600, out_features=300, bias=True)
#             (1): Linear(in_features=300, out_features=300, bias=True)
#           )
#           (bypass_networks): ModuleList(
#             (0): Bypass(
#               (highway_gate): Linear(in_features=600, out_features=300, bias=True)
#             )
#             (1): Bypass(
#               (highway_gate): Linear(in_features=300, out_features=300, bias=True)
#             )
#           )
#         )
#         (input_dropout): Dropout(p=0)
#         (transform_dropout): Dropout(p=0)
#         (score_dropout): Dropout(p=0)
#         (softmax): Softmax()
#       )
#       (word_aggregator): AttentionWithRNN(
#         (rnn): RNN(
#           (rnn_groups): ModuleList(
#             (0): GRU(300, 150, batch_first=True, bidirectional=True)
#           )
#           (dropouts): ModuleList(
#             (0): Dropout(p=0)
#           )
#           (bypass_networks): ModuleList(
#             (0): None
#           )
#           (input_dropout): NoMeta(
#             (module): Dropout(p=0)
#           )
#         )
#         (rnn_pool): Pool(
#         )
#         (input_context_comparison_network): Transform(
#           (transforms): ModuleList(
#             (0): Linear(in_features=600, out_features=300, bias=True)
#           )
#           (bypass_networks): ModuleList(
#             (0): Bypass(
#               (highway_gate): Linear(in_features=600, out_features=300, bias=True)
#             )
#           )
#         )
#         (scoring_network): Transform(
#           (transforms): ModuleList(
#             (0): Linear(in_features=300, out_features=1, bias=True)
#           )
#           (bypass_networks): ModuleList(
#             (0): None
#           )
#         )
#         (input_dropout): Dropout(p=0)
#         (transform_dropout): Dropout(p=0)
#         (score_dropout): Dropout(p=0)
#         (softmax): Softmax()
#       )
#     )
#     (CopyRight): Hybrid(
#       (word_contextualizer): RNN(
#         (rnn_groups): ModuleList(
#           (0): GRU(300, 150, batch_first=True, bidirectional=True)
#         )
#         (dropouts): ModuleList(
#           (0): Dropout(p=0)
#         )
#         (bypass_networks): ModuleList(
#           (0): None
#         )
#         (input_dropout): NoMeta(
#           (module): Dropout(p=0)
#         )
#       )
#       (word_comparator): Attention(
#         (alignment_networks): ModuleList(
#           (0): AlignmentNetwork(
#             (transform): Transform(
#               (transforms): ModuleList(
#                 (0): Linear(in_features=300, out_features=300, bias=True)
#                 (1): Linear(in_features=300, out_features=300, bias=True)
#               )
#               (bypass_networks): ModuleList(
#                 (0): Bypass(
#                   (highway_gate): Linear(in_features=300, out_features=300, bias=True)
#                 )
#                 (1): Bypass(
#                   (highway_gate): Linear(in_features=300, out_features=300, bias=True)
#                 )
#               )
#             )
#           )
#         )
#         (value_merge): Merge(
#         )
#         (comparison_merge): Merge(
#         )
#         (comparison_network): Transform(
#           (transforms): ModuleList(
#             (0): Linear(in_features=600, out_features=300, bias=True)
#             (1): Linear(in_features=300, out_features=300, bias=True)
#           )
#           (bypass_networks): ModuleList(
#             (0): Bypass(
#               (highway_gate): Linear(in_features=600, out_features=300, bias=True)
#             )
#             (1): Bypass(
#               (highway_gate): Linear(in_features=300, out_features=300, bias=True)
#             )
#           )
#         )
#         (input_dropout): Dropout(p=0)
#         (transform_dropout): Dropout(p=0)
#         (score_dropout): Dropout(p=0)
#         (softmax): Softmax()
#       )
#       (word_aggregator): AttentionWithRNN(
#         (rnn): RNN(
#           (rnn_groups): ModuleList(
#             (0): GRU(300, 150, batch_first=True, bidirectional=True)
#           )
#           (dropouts): ModuleList(
#             (0): Dropout(p=0)
#           )
#           (bypass_networks): ModuleList(
#             (0): None
#           )
#           (input_dropout): NoMeta(
#             (module): Dropout(p=0)
#           )
#         )
#         (rnn_pool): Pool(
#         )
#         (input_context_comparison_network): Transform(
#           (transforms): ModuleList(
#             (0): Linear(in_features=600, out_features=300, bias=True)
#           )
#           (bypass_networks): ModuleList(
#             (0): Bypass(
#               (highway_gate): Linear(in_features=600, out_features=300, bias=True)
#             )
#           )
#         )
#         (scoring_network): Transform(
#           (transforms): ModuleList(
#             (0): Linear(in_features=300, out_features=1, bias=True)
#           )
#           (bypass_networks): ModuleList(
#             (0): None
#           )
#         )
#         (input_dropout): Dropout(p=0)
#         (transform_dropout): Dropout(p=0)
#         (score_dropout): Dropout(p=0)
#         (softmax): Softmax()
#       )
#     )
#     (Time): Hybrid(
#       (word_contextualizer): RNN(
#         (rnn_groups): ModuleList(
#           (0): GRU(300, 150, batch_first=True, bidirectional=True)
#         )
#         (dropouts): ModuleList(
#           (0): Dropout(p=0)
#         )
#         (bypass_networks): ModuleList(
#           (0): None
#         )
#         (input_dropout): NoMeta(
#           (module): Dropout(p=0)
#         )
#       )
#       (word_comparator): Attention(
#         (alignment_networks): ModuleList(
#           (0): AlignmentNetwork(
#             (transform): Transform(
#               (transforms): ModuleList(
#                 (0): Linear(in_features=300, out_features=300, bias=True)
#                 (1): Linear(in_features=300, out_features=300, bias=True)
#               )
#               (bypass_networks): ModuleList(
#                 (0): Bypass(
#                   (highway_gate): Linear(in_features=300, out_features=300, bias=True)
#                 )
#                 (1): Bypass(
#                   (highway_gate): Linear(in_features=300, out_features=300, bias=True)
#                 )
#               )
#             )
#           )
#         )
#         (value_merge): Merge(
#         )
#         (comparison_merge): Merge(
#         )
#         (comparison_network): Transform(
#           (transforms): ModuleList(
#             (0): Linear(in_features=600, out_features=300, bias=True)
#             (1): Linear(in_features=300, out_features=300, bias=True)
#           )
#           (bypass_networks): ModuleList(
#             (0): Bypass(
#               (highway_gate): Linear(in_features=600, out_features=300, bias=True)
#             )
#             (1): Bypass(
#               (highway_gate): Linear(in_features=300, out_features=300, bias=True)
#             )
#           )
#         )
#         (input_dropout): Dropout(p=0)
#         (transform_dropout): Dropout(p=0)
#         (score_dropout): Dropout(p=0)
#         (softmax): Softmax()
#       )
#       (word_aggregator): AttentionWithRNN(
#         (rnn): RNN(
#           (rnn_groups): ModuleList(
#             (0): GRU(300, 150, batch_first=True, bidirectional=True)
#           )
#           (dropouts): ModuleList(
#             (0): Dropout(p=0)
#           )
#           (bypass_networks): ModuleList(
#             (0): None
#           )
#           (input_dropout): NoMeta(
#             (module): Dropout(p=0)
#           )
#         )
#         (rnn_pool): Pool(
#         )
#         (input_context_comparison_network): Transform(
#           (transforms): ModuleList(
#             (0): Linear(in_features=600, out_features=300, bias=True)
#           )
#           (bypass_networks): ModuleList(
#             (0): Bypass(
#               (highway_gate): Linear(in_features=600, out_features=300, bias=True)
#             )
#           )
#         )
#         (scoring_network): Transform(
#           (transforms): ModuleList(
#             (0): Linear(in_features=300, out_features=1, bias=True)
#           )
#           (bypass_networks): ModuleList(
#             (0): None
#           )
#         )
#         (input_dropout): Dropout(p=0)
#         (transform_dropout): Dropout(p=0)
#         (score_dropout): Dropout(p=0)
#         (softmax): Softmax()
#       )
#     )
#     (Released): Hybrid(
#       (word_contextualizer): RNN(
#         (rnn_groups): ModuleList(
#           (0): GRU(300, 150, batch_first=True, bidirectional=True)
#         )
#         (dropouts): ModuleList(
#           (0): Dropout(p=0)
#         )
#         (bypass_networks): ModuleList(
#           (0): None
#         )
#         (input_dropout): NoMeta(
#           (module): Dropout(p=0)
#         )
#       )
#       (word_comparator): Attention(
#         (alignment_networks): ModuleList(
#           (0): AlignmentNetwork(
#             (transform): Transform(
#               (transforms): ModuleList(
#                 (0): Linear(in_features=300, out_features=300, bias=True)
#                 (1): Linear(in_features=300, out_features=300, bias=True)
#               )
#               (bypass_networks): ModuleList(
#                 (0): Bypass(
#                   (highway_gate): Linear(in_features=300, out_features=300, bias=True)
#                 )
#                 (1): Bypass(
#                   (highway_gate): Linear(in_features=300, out_features=300, bias=True)
#                 )
#               )
#             )
#           )
#         )
#         (value_merge): Merge(
#         )
#         (comparison_merge): Merge(
#         )
#         (comparison_network): Transform(
#           (transforms): ModuleList(
#             (0): Linear(in_features=600, out_features=300, bias=True)
#             (1): Linear(in_features=300, out_features=300, bias=True)
#           )
#           (bypass_networks): ModuleList(
#             (0): Bypass(
#               (highway_gate): Linear(in_features=600, out_features=300, bias=True)
#             )
#             (1): Bypass(
#               (highway_gate): Linear(in_features=300, out_features=300, bias=True)
#             )
#           )
#         )
#         (input_dropout): Dropout(p=0)
#         (transform_dropout): Dropout(p=0)
#         (score_dropout): Dropout(p=0)
#         (softmax): Softmax()
#       )
#       (word_aggregator): AttentionWithRNN(
#         (rnn): RNN(
#           (rnn_groups): ModuleList(
#             (0): GRU(300, 150, batch_first=True, bidirectional=True)
#           )
#           (dropouts): ModuleList(
#             (0): Dropout(p=0)
#           )
#           (bypass_networks): ModuleList(
#             (0): None
#           )
#           (input_dropout): NoMeta(
#             (module): Dropout(p=0)
#           )
#         )
#         (rnn_pool): Pool(
#         )
#         (input_context_comparison_network): Transform(
#           (transforms): ModuleList(
#             (0): Linear(in_features=600, out_features=300, bias=True)
#           )
#           (bypass_networks): ModuleList(
#             (0): Bypass(
#               (highway_gate): Linear(in_features=600, out_features=300, bias=True)
#             )
#           )
#         )
#         (scoring_network): Transform(
#           (transforms): ModuleList(
#             (0): Linear(in_features=300, out_features=1, bias=True)
#           )
#           (bypass_networks): ModuleList(
#             (0): None
#           )
#         )
#         (input_dropout): Dropout(p=0)
#         (transform_dropout): Dropout(p=0)
#         (score_dropout): Dropout(p=0)
#         (softmax): Softmax()
#       )
#     )
#   )
#   (attr_summarizer): Hybrid(
#   )
#   (attr_condensors): ModuleMap(
#     (Song_Name): Transform(
#       (transforms): ModuleList(
#         (0): Linear(in_features=300, out_features=50, bias=True)
#       )
#       (bypass_networks): ModuleList(
#         (0): Bypass(
#           (highway_gate): Linear(in_features=300, out_features=50, bias=True)
#         )
#       )
#     )
#     (Artist_Name): Transform(
#       (transforms): ModuleList(
#         (0): Linear(in_features=300, out_features=50, bias=True)
#       )
#       (bypass_networks): ModuleList(
#         (0): Bypass(
#           (highway_gate): Linear(in_features=300, out_features=50, bias=True)
#         )
#       )
#     )
#     (Album_Name): Transform(
#       (transforms): ModuleList(
#         (0): Linear(in_features=300, out_features=50, bias=True)
#       )
#       (bypass_networks): ModuleList(
#         (0): Bypass(
#           (highway_gate): Linear(in_features=300, out_features=50, bias=True)
#         )
#       )
#     )
#     (Genre): Transform(
#       (transforms): ModuleList(
#         (0): Linear(in_features=300, out_features=50, bias=True)
#       )
#       (bypass_networks): ModuleList(
#         (0): Bypass(
#           (highway_gate): Linear(in_features=300, out_features=50, bias=True)
#         )
#       )
#     )
#     (Price): Transform(
#       (transforms): ModuleList(
#         (0): Linear(in_features=300, out_features=50, bias=True)
#       )
#       (bypass_networks): ModuleList(
#         (0): Bypass(
#           (highway_gate): Linear(in_features=300, out_features=50, bias=True)
#         )
#       )
#     )
#     (CopyRight): Transform(
#       (transforms): ModuleList(
#         (0): Linear(in_features=300, out_features=50, bias=True)
#       )
#       (bypass_networks): ModuleList(
#         (0): Bypass(
#           (highway_gate): Linear(in_features=300, out_features=50, bias=True)
#         )
#       )
#     )
#     (Time): Transform(
#       (transforms): ModuleList(
#         (0): Linear(in_features=300, out_features=50, bias=True)
#       )
#       (bypass_networks): ModuleList(
#         (0): Bypass(
#           (highway_gate): Linear(in_features=300, out_features=50, bias=True)
#         )
#       )
#     )
#     (Released): Transform(
#       (transforms): ModuleList(
#         (0): Linear(in_features=300, out_features=50, bias=True)
#       )
#       (bypass_networks): ModuleList(
#         (0): Bypass(
#           (highway_gate): Linear(in_features=300, out_features=50, bias=True)
#         )
#       )
#     )
#   )
#   (attr_comparators): ModuleMap(
#     (Song_Name): Merge(
#     )
#     (Artist_Name): Merge(
#     )
#     (Album_Name): Merge(
#     )
#     (Genre): Merge(
#     )
#     (Price): Merge(
#     )
#     (CopyRight): Merge(
#     )
#     (Time): Merge(
#     )
#     (Released): Merge(
#     )
#   )
#   (attr_comparator): Merge(
#   )
#   (attr_merge): Merge(
#   )
#   (classifier): Classifier(
#     (transform): Transform(
#       (transforms): ModuleList(
#         (0): Linear(in_features=1200, out_features=300, bias=True)
#         (1): Linear(in_features=300, out_features=300, bias=True)
#       )
#       (bypass_networks): ModuleList(
#         (0): Bypass(
#           (highway_gate): Linear(in_features=1200, out_features=300, bias=True)
#         )
#         (1): Bypass(
#           (highway_gate): Linear(in_features=300, out_features=300, bias=True)
#         )
#       )
#     )
#     (softmax_transform): Transform(
#       (transforms): ModuleList(
#         (0): Linear(in_features=300, out_features=2, bias=True)
#       )
#       (bypass_networks): ModuleList(
#         (0): None
#       )
#     )
#     (softmax): LogSoftmax()
#   )
#   (embed): ModuleMap(
#     (left_Song_Name): NoMeta(
#       (module): Embedding(2321, 300)
#     )
#     (left_Artist_Name): NoMeta(
#       (module): Embedding(2321, 300)
#     )
#     (left_Album_Name): NoMeta(
#       (module): Embedding(2321, 300)
#     )
#     (left_Genre): NoMeta(
#       (module): Embedding(2321, 300)
#     )
#     (left_Price): NoMeta(
#       (module): Embedding(2321, 300)
#     )
#     (left_CopyRight): NoMeta(
#       (module): Embedding(2321, 300)
#     )
#     (left_Time): NoMeta(
#       (module): Embedding(2321, 300)
#     )
#     (left_Released): NoMeta(
#       (module): Embedding(2321, 300)
#     )
#     (right_Song_Name): NoMeta(
#       (module): Embedding(2321, 300)
#     )
#     (right_Artist_Name): NoMeta(
#       (module): Embedding(2321, 300)
#     )
#     (right_Album_Name): NoMeta(
#       (module): Embedding(2321, 300)
#     )
#     (right_Genre): NoMeta(
#       (module): Embedding(2321, 300)
#     )
#     (right_Price): NoMeta(
#       (module): Embedding(2321, 300)
#     )
#     (right_CopyRight): NoMeta(
#       (module): Embedding(2321, 300)
#     )
#     (right_Time): NoMeta(
#       (module): Embedding(2321, 300)
#     )
#     (right_Released): NoMeta(
#       (module): Embedding(2321, 300)
#     )
#   )
# )

# %%
hybrid_model_numericencoding.run_train(train,valid,'models/hybrid_numericencoding.pth',epochs=30,
                                      pos_neg_ration=4,batch_size=16)

# %% [markdown]
# ## Datasets creation

# %%
attributes = ['Song_Name','Artist_Name','Album_Name','Genre','Price','CopyRight','Time','Released']

# %%
neg_dataset = dm.data.process(path='sample_data/itunes-amazon/exp4',train='all_negatives_numericencoding.csv',
                            validation='validation_numericencoding.csv',cache='exp4_neg.pth')

# %%
classifier = hybrid_model_numericencoding.classifier
hookF_classifier = []
hookF_classifier.append(Hook(classifier))

# %%
batch_size = 32
splits = MatchingIterator.splits(neg_dataset,batch_size=batch_size)

# %%
negative_batches = []
for batch in splits[0]:
    negative_batches.append(batch)

# %%
negative_classifier_inputs = []
negative_classifier_outputs = []
for batch in negative_batches:
    classifier_input,classifier_output = return_layer_input_output(hookF_classifier,batch,hybrid_model_numericencoding)
    negative_classifier_inputs.append(classifier_input)
    negative_classifier_outputs.append(classifier_output)

# %%
negative_classifier_inputs = list(map(lambda x: x[0][0],negative_classifier_inputs))
negative_classifier_outputs = list(map(lambda x: x[0][0],negative_classifier_outputs))

# %%
pos_dataset = dm.data.process(path='sample_data/itunes-amazon/exp4',train='all_positives_numericencoding.csv',
                            validation='validation_numericencoding.csv',cache='exp4_pos.pth')

# %%
batch_size = 32
splits = MatchingIterator.splits(pos_dataset,batch_size=batch_size)

# %%
positive_batches = []
for batch in splits[0]:
    positive_batches.append(batch)

# %%
positive_classifier_inputs = []
positive_classifier_outputs = []
for batch in positive_batches:
    classifier_input,classifier_output = return_layer_input_output(hookF_classifier,batch,hybrid_model_numericencoding)
    positive_classifier_inputs.append(classifier_input)
    positive_classifier_outputs.append(classifier_output)

# %%
positive_classifier_inputs = list(map(lambda x: x[0][0],positive_classifier_inputs))
positive_classifier_outputs = list(map(lambda x: x[0][0],positive_classifier_outputs))

# %% [markdown]
# ## Utility methods

# %%
from utilities_functions.distance_measures import find_smallest_variation_to_change

# %% [markdown]
# ## Negative sample analysis

# %%
attribute_lenght= len(attributes)

current_sample = 0
#each column of this matrix is related to a specific attribute
negatives_ri_matrix = []
for batch in negative_classifier_inputs:
    for index in range(len(batch)):
        current_sample_ris = []
        for j,attribute in enumerate(attributes):
            print('Processing sample {} with attribute {}'.format(current_sample,attribute))
            it,variation = find_smallest_variation_to_change(hybrid_model_numericencoding.classifier,batch,index,j,1)
            current_sample_ris.append(variation)
        negatives_ri_matrix.append(current_sample_ris)
        current_sample+=1
# Out:
# Processing sample 0 with attribute Song_Name
# Processing sample 0 with attribute Artist_Name
# Processing sample 0 with attribute Album_Name
# Processing sample 0 with attribute Genre
# Processing sample 0 with attribute Price
# Processing sample 0 with attribute CopyRight
# Processing sample 0 with attribute Time
# Processing sample 0 with attribute Released
# Processing sample 1 with attribute Song_Name
# Processing sample 1 with attribute Artist_Name
# Processing sample 1 with attribute Album_Name
# Processing sample 1 with attribute Genre
# Processing sample 1 with attribute Price
# Processing sample 1 with attribute CopyRight
# Processing sample 1 with attribute Time
# Processing sample 1 with attribute Released
# Processing sample 2 with attribute Song_Name
# Processing sample 2 with attribute Artist_Name
# Processing sample 2 with attribute Album_Name
# Processing sample 2 with attribute Genre
# Processing sample 2 with attribute Price
# Processing sample 2 with attribute CopyRight
# Processing sample 2 with attribute Time
# Processing sample 2 with attribute Released
# Processing sample 3 with attribute Song_Name
# Processing sample 3 with attribute Artist_Name
# Processing sample 3 with attribute Album_Name
# Processing sample 3 with attribute Genre
# Processing sample 3 with attribute Price
# Processing sample 3 with attribute CopyRight
# Processing sample 3 with attribute Time
# Processing sample 3 with attribute Released
# Processing sample 4 with attribute Song_Name
# Processing sample 4 with attribute Artist_Name
# Processing sample 4 with attribute Album_Name
# Processing sample 4 with attribute Genre
# Processing sample 4 with attribute Price
# Processing sample 4 with attribute CopyRight
# Processing sample 4 with attribute Time
# Processing sample 4 with attribute Released
# Processing sample 5 with attribute Song_Name
# Processing sample 5 with attribute Artist_Name
# Processing sample 5 with attribute Album_Name
# Processing sample 5 with attribute Genre
# Processing sample 5 with attribute Price
# Processing sample 5 with attribute CopyRight
# Processing sample 5 with attribute Time
# Processing sample 5 with attribute Released
# Processing sample 6 with attribute Song_Name
# Processing sample 6 with attribute Artist_Name
# Processing sample 6 with attribute Album_Name
# Processing sample 6 with attribute Genre
# Processing sample 6 with attribute Price
# Processing sample 6 with attribute CopyRight
# Processing sample 6 with attribute Time
# Processing sample 6 with attribute Released
# Processing sample 7 with attribute Song_Name
# Processing sample 7 with attribute Artist_Name
# Processing sample 7 with attribute Album_Name
# Processing sample 7 with attribute Genre
# Processing sample 7 with attribute Price
# Processing sample 7 with attribute CopyRight
# Processing sample 7 with attribute Time
# Processing sample 7 with attribute Released
# Processing sample 8 with attribute Song_Name
# Processing sample 8 with attribute Artist_Name
# Processing sample 8 with attribute Album_Name
# Processing sample 8 with attribute Genre
# Processing sample 8 with attribute Price
# Processing sample 8 with attribute CopyRight
# Processing sample 8 with attribute Time
# Processing sample 8 with attribute Released
# Processing sample 9 with attribute Song_Name
# Processing sample 9 with attribute Artist_Name
# Processing sample 9 with attribute Album_Name
# Processing sample 9 with attribute Genre
# Processing sample 9 with attribute Price
# Processing sample 9 with attribute CopyRight
# Processing sample 9 with attribute Time
# Processing sample 9 with attribute Released
# Processing sample 10 with attribute Song_Name
# Processing sample 10 with attribute Artist_Name
# Processing sample 10 with attribute Album_Name
# Processing sample 10 with attribute Genre
# Processing sample 10 with attribute Price
# Processing sample 10 with attribute CopyRight
# Processing sample 10 with attribute Time
# Processing sample 10 with attribute Released
# Processing sample 11 with attribute Song_Name
# Processing sample 11 with attribute Artist_Name
# Processing sample 11 with attribute Album_Name
# Processing sample 11 with attribute Genre
# Processing sample 11 with attribute Price
# Processing sample 11 with attribute CopyRight
# Processing sample 11 with attribute Time
# Processing sample 11 with attribute Released
# Processing sample 12 with attribute Song_Name
# Processing sample 12 with attribute Artist_Name
# Processing sample 12 with attribute Album_Name
# Processing sample 12 with attribute Genre
# Processing sample 12 with attribute Price
# Processing sample 12 with attribute CopyRight
# Processing sample 12 with attribute Time
# Processing sample 12 with attribute Released
# Processing sample 13 with attribute Song_Name
# Processing sample 13 with attribute Artist_Name
# Processing sample 13 with attribute Album_Name
# Processing sample 13 with attribute Genre
# Processing sample 13 with attribute Price
# Processing sample 13 with attribute CopyRight
# Processing sample 13 with attribute Time
# Processing sample 13 with attribute Released
# Processing sample 14 with attribute Song_Name
# Processing sample 14 with attribute Artist_Name
# Processing sample 14 with attribute Album_Name
# Processing sample 14 with attribute Genre
# Processing sample 14 with attribute Price
# Processing sample 14 with attribute CopyRight
# Processing sample 14 with attribute Time
# Processing sample 14 with attribute Released
# Processing sample 15 with attribute Song_Name
# Processing sample 15 with attribute Artist_Name
# Processing sample 15 with attribute Album_Name
# Processing sample 15 with attribute Genre
# Processing sample 15 with attribute Price
# Processing sample 15 with attribute CopyRight
# Processing sample 15 with attribute Time
# Processing sample 15 with attribute Released
# Processing sample 16 with attribute Song_Name
# Processing sample 16 with attribute Artist_Name
# Processing sample 16 with attribute Album_Name
# Processing sample 16 with attribute Genre
# Processing sample 16 with attribute Price
# Processing sample 16 with attribute CopyRight
# Processing sample 16 with attribute Time
# Processing sample 16 with attribute Released
# Processing sample 17 with attribute Song_Name
# Processing sample 17 with attribute Artist_Name
# Processing sample 17 with attribute Album_Name
# Processing sample 17 with attribute Genre
# Processing sample 17 with attribute Price
# Processing sample 17 with attribute CopyRight
# Processing sample 17 with attribute Time
# Processing sample 17 with attribute Released
# Processing sample 18 with attribute Song_Name
# Processing sample 18 with attribute Artist_Name
# Processing sample 18 with attribute Album_Name
# Processing sample 18 with attribute Genre
# Processing sample 18 with attribute Price
# Processing sample 18 with attribute CopyRight
# Processing sample 18 with attribute Time
# Processing sample 18 with attribute Released
# Processing sample 19 with attribute Song_Name
# Processing sample 19 with attribute Artist_Name
# Processing sample 19 with attribute Album_Name
# Processing sample 19 with attribute Genre
# Processing sample 19 with attribute Price
# Processing sample 19 with attribute CopyRight
# Processing sample 19 with attribute Time
# Processing sample 19 with attribute Released
# Processing sample 20 with attribute Song_Name
# Processing sample 20 with attribute Artist_Name
# Processing sample 20 with attribute Album_Name
# Processing sample 20 with attribute Genre
# Processing sample 20 with attribute Price
# Processing sample 20 with attribute CopyRight
# Processing sample 20 with attribute Time
# Processing sample 20 with attribute Released
# Processing sample 21 with attribute Song_Name
# Processing sample 21 with attribute Artist_Name
# Processing sample 21 with attribute Album_Name
# Processing sample 21 with attribute Genre
# Processing sample 21 with attribute Price
# Processing sample 21 with attribute CopyRight
# Processing sample 21 with attribute Time
# Processing sample 21 with attribute Released
# Processing sample 22 with attribute Song_Name
# Processing sample 22 with attribute Artist_Name
# Processing sample 22 with attribute Album_Name
# Processing sample 22 with attribute Genre
# Processing sample 22 with attribute Price
# Processing sample 22 with attribute CopyRight
# Processing sample 22 with attribute Time
# Processing sample 22 with attribute Released
# Processing sample 23 with attribute Song_Name
# Processing sample 23 with attribute Artist_Name
# Processing sample 23 with attribute Album_Name
# Processing sample 23 with attribute Genre
# Processing sample 23 with attribute Price
# Processing sample 23 with attribute CopyRight
# Processing sample 23 with attribute Time
# Processing sample 23 with attribute Released
# Processing sample 24 with attribute Song_Name
# Processing sample 24 with attribute Artist_Name
# Processing sample 24 with attribute Album_Name
# Processing sample 24 with attribute Genre
# Processing sample 24 with attribute Price
# Processing sample 24 with attribute CopyRight
# Processing sample 24 with attribute Time
# Processing sample 24 with attribute Released
# Processing sample 25 with attribute Song_Name
# Processing sample 25 with attribute Artist_Name
# Processing sample 25 with attribute Album_Name
# Processing sample 25 with attribute Genre
# Processing sample 25 with attribute Price
# Processing sample 25 with attribute CopyRight
# Processing sample 25 with attribute Time
# Processing sample 25 with attribute Released
# Processing sample 26 with attribute Song_Name
# Processing sample 26 with attribute Artist_Name
# Processing sample 26 with attribute Album_Name
# Processing sample 26 with attribute Genre
# Processing sample 26 with attribute Price
# Processing sample 26 with attribute CopyRight
# Processing sample 26 with attribute Time
# Processing sample 26 with attribute Released
# Processing sample 27 with attribute Song_Name
# Processing sample 27 with attribute Artist_Name
# Processing sample 27 with attribute Album_Name
# Processing sample 27 with attribute Genre
# Processing sample 27 with attribute Price
# Processing sample 27 with attribute CopyRight
# Processing sample 27 with attribute Time
# Processing sample 27 with attribute Released
# Processing sample 28 with attribute Song_Name
# Processing sample 28 with attribute Artist_Name
# Processing sample 28 with attribute Album_Name
# Processing sample 28 with attribute Genre
# Processing sample 28 with attribute Price
# Processing sample 28 with attribute CopyRight
# Processing sample 28 with attribute Time
# Processing sample 28 with attribute Released
# Processing sample 29 with attribute Song_Name
# Processing sample 29 with attribute Artist_Name
# Processing sample 29 with attribute Album_Name
# Processing sample 29 with attribute Genre
# Processing sample 29 with attribute Price
# Processing sample 29 with attribute CopyRight
# Processing sample 29 with attribute Time
# Processing sample 29 with attribute Released
# Processing sample 30 with attribute Song_Name
# Processing sample 30 with attribute Artist_Name
# Processing sample 30 with attribute Album_Name
# Processing sample 30 with attribute Genre
# Processing sample 30 with attribute Price
# Processing sample 30 with attribute CopyRight
# Processing sample 30 with attribute Time
# Processing sample 30 with attribute Released
# Processing sample 31 with attribute Song_Name
# Processing sample 31 with attribute Artist_Name
# Processing sample 31 with attribute Album_Name
# Processing sample 31 with attribute Genre
# Processing sample 31 with attribute Price
# Processing sample 31 with attribute CopyRight
# Processing sample 31 with attribute Time
# Processing sample 31 with attribute Released
# Processing sample 32 with attribute Song_Name
# Processing sample 32 with attribute Artist_Name
# Processing sample 32 with attribute Album_Name
# Processing sample 32 with attribute Genre
# Processing sample 32 with attribute Price
# Processing sample 32 with attribute CopyRight
# Processing sample 32 with attribute Time
# Processing sample 32 with attribute Released
# Processing sample 33 with attribute Song_Name
# Processing sample 33 with attribute Artist_Name
# Processing sample 33 with attribute Album_Name
# Processing sample 33 with attribute Genre
# Processing sample 33 with attribute Price
# Processing sample 33 with attribute CopyRight
# Processing sample 33 with attribute Time
# Processing sample 33 with attribute Released
# Processing sample 34 with attribute Song_Name
# Processing sample 34 with attribute Artist_Name
# Processing sample 34 with attribute Album_Name
# Processing sample 34 with attribute Genre
# Processing sample 34 with attribute Price
# Processing sample 34 with attribute CopyRight
# Processing sample 34 with attribute Time
# Processing sample 34 with attribute Released
# Processing sample 35 with attribute Song_Name
# Processing sample 35 with attribute Artist_Name
# Processing sample 35 with attribute Album_Name
# Processing sample 35 with attribute Genre
# Processing sample 35 with attribute Price
# Processing sample 35 with attribute CopyRight
# Processing sample 35 with attribute Time
# Processing sample 35 with attribute Released
# Processing sample 36 with attribute Song_Name
# Processing sample 36 with attribute Artist_Name
# Processing sample 36 with attribute Album_Name
# Processing sample 36 with attribute Genre
# Processing sample 36 with attribute Price
# Processing sample 36 with attribute CopyRight
# Processing sample 36 with attribute Time
# Processing sample 36 with attribute Released
# Processing sample 37 with attribute Song_Name
# Processing sample 37 with attribute Artist_Name
# Processing sample 37 with attribute Album_Name
# Processing sample 37 with attribute Genre
# Processing sample 37 with attribute Price
# Processing sample 37 with attribute CopyRight
# Processing sample 37 with attribute Time
# Processing sample 37 with attribute Released
# Processing sample 38 with attribute Song_Name
# Processing sample 38 with attribute Artist_Name
# Processing sample 38 with attribute Album_Name
# Processing sample 38 with attribute Genre
# Processing sample 38 with attribute Price
# Processing sample 38 with attribute CopyRight
# Processing sample 38 with attribute Time
# Processing sample 38 with attribute Released
# Processing sample 39 with attribute Song_Name
# Processing sample 39 with attribute Artist_Name
# Processing sample 39 with attribute Album_Name
# Processing sample 39 with attribute Genre
# Processing sample 39 with attribute Price
# Processing sample 39 with attribute CopyRight
# Processing sample 39 with attribute Time
# Processing sample 39 with attribute Released
# Processing sample 40 with attribute Song_Name
# Processing sample 40 with attribute Artist_Name
# Processing sample 40 with attribute Album_Name
# Processing sample 40 with attribute Genre
# Processing sample 40 with attribute Price
# Processing sample 40 with attribute CopyRight
# Processing sample 40 with attribute Time
# Processing sample 40 with attribute Released
# Processing sample 41 with attribute Song_Name
# Processing sample 41 with attribute Artist_Name
# Processing sample 41 with attribute Album_Name
# Processing sample 41 with attribute Genre
# Processing sample 41 with attribute Price
# Processing sample 41 with attribute CopyRight
# Processing sample 41 with attribute Time
# Processing sample 41 with attribute Released
# Processing sample 42 with attribute Song_Name
# Processing sample 42 with attribute Artist_Name
# Processing sample 42 with attribute Album_Name
# Processing sample 42 with attribute Genre
# Processing sample 42 with attribute Price
# Processing sample 42 with attribute CopyRight
# Processing sample 42 with attribute Time
# Processing sample 42 with attribute Released
# Processing sample 43 with attribute Song_Name
# Processing sample 43 with attribute Artist_Name
# Processing sample 43 with attribute Album_Name
# Processing sample 43 with attribute Genre
# Processing sample 43 with attribute Price
# Processing sample 43 with attribute CopyRight
# Processing sample 43 with attribute Time
# Processing sample 43 with attribute Released
# Processing sample 44 with attribute Song_Name
# Processing sample 44 with attribute Artist_Name
# Processing sample 44 with attribute Album_Name
# Processing sample 44 with attribute Genre
# Processing sample 44 with attribute Price
# Processing sample 44 with attribute CopyRight
# Processing sample 44 with attribute Time
# Processing sample 44 with attribute Released
# Processing sample 45 with attribute Song_Name
# Processing sample 45 with attribute Artist_Name
# Processing sample 45 with attribute Album_Name
# Processing sample 45 with attribute Genre
# Processing sample 45 with attribute Price
# Processing sample 45 with attribute CopyRight
# Processing sample 45 with attribute Time
# Processing sample 45 with attribute Released
# Processing sample 46 with attribute Song_Name
# Processing sample 46 with attribute Artist_Name
# Processing sample 46 with attribute Album_Name
# Processing sample 46 with attribute Genre
# Processing sample 46 with attribute Price
# Processing sample 46 with attribute CopyRight
# Processing sample 46 with attribute Time
# Processing sample 46 with attribute Released
# Processing sample 47 with attribute Song_Name
# Processing sample 47 with attribute Artist_Name
# Processing sample 47 with attribute Album_Name
# Processing sample 47 with attribute Genre
# Processing sample 47 with attribute Price
# Processing sample 47 with attribute CopyRight
# Processing sample 47 with attribute Time
# Processing sample 47 with attribute Released
# Processing sample 48 with attribute Song_Name
# Processing sample 48 with attribute Artist_Name
# Processing sample 48 with attribute Album_Name
# Processing sample 48 with attribute Genre
# Processing sample 48 with attribute Price
# Processing sample 48 with attribute CopyRight
# Processing sample 48 with attribute Time
# Processing sample 48 with attribute Released
# Processing sample 49 with attribute Song_Name
# Processing sample 49 with attribute Artist_Name
# Processing sample 49 with attribute Album_Name
# Processing sample 49 with attribute Genre
# Processing sample 49 with attribute Price
# Processing sample 49 with attribute CopyRight
# Processing sample 49 with attribute Time
# Processing sample 49 with attribute Released
# Processing sample 50 with attribute Song_Name
# Processing sample 50 with attribute Artist_Name
# Processing sample 50 with attribute Album_Name
# Processing sample 50 with attribute Genre
# Processing sample 50 with attribute Price
# Processing sample 50 with attribute CopyRight
# Processing sample 50 with attribute Time
# Processing sample 50 with attribute Released
# Processing sample 51 with attribute Song_Name
# Processing sample 51 with attribute Artist_Name
# Processing sample 51 with attribute Album_Name
# Processing sample 51 with attribute Genre
# Processing sample 51 with attribute Price
# Processing sample 51 with attribute CopyRight
# Processing sample 51 with attribute Time
# Processing sample 51 with attribute Released
# Processing sample 52 with attribute Song_Name
# Processing sample 52 with attribute Artist_Name
# Processing sample 52 with attribute Album_Name
# Processing sample 52 with attribute Genre
# Processing sample 52 with attribute Price
# Processing sample 52 with attribute CopyRight
# Processing sample 52 with attribute Time
# Processing sample 52 with attribute Released
# Processing sample 53 with attribute Song_Name
# Processing sample 53 with attribute Artist_Name
# Processing sample 53 with attribute Album_Name
# Processing sample 53 with attribute Genre
# Processing sample 53 with attribute Price
# Processing sample 53 with attribute CopyRight
# Processing sample 53 with attribute Time
# Processing sample 53 with attribute Released
# Processing sample 54 with attribute Song_Name
# Processing sample 54 with attribute Artist_Name
# Processing sample 54 with attribute Album_Name
# Processing sample 54 with attribute Genre
# Processing sample 54 with attribute Price
# Processing sample 54 with attribute CopyRight
# Processing sample 54 with attribute Time
# Processing sample 54 with attribute Released
# Processing sample 55 with attribute Song_Name
# Processing sample 55 with attribute Artist_Name
# Processing sample 55 with attribute Album_Name
# Processing sample 55 with attribute Genre
# Processing sample 55 with attribute Price
# Processing sample 55 with attribute CopyRight
# Processing sample 55 with attribute Time
# Processing sample 55 with attribute Released
# Processing sample 56 with attribute Song_Name
# Processing sample 56 with attribute Artist_Name
# Processing sample 56 with attribute Album_Name
# Processing sample 56 with attribute Genre
# Processing sample 56 with attribute Price
# Processing sample 56 with attribute CopyRight
# Processing sample 56 with attribute Time
# Processing sample 56 with attribute Released
# Processing sample 57 with attribute Song_Name
# Processing sample 57 with attribute Artist_Name
# Processing sample 57 with attribute Album_Name
# Processing sample 57 with attribute Genre
# Processing sample 57 with attribute Price
# Processing sample 57 with attribute CopyRight
# Processing sample 57 with attribute Time
# Processing sample 57 with attribute Released
# Processing sample 58 with attribute Song_Name
# Processing sample 58 with attribute Artist_Name
# Processing sample 58 with attribute Album_Name
# Processing sample 58 with attribute Genre
# Processing sample 58 with attribute Price
# Processing sample 58 with attribute CopyRight
# Processing sample 58 with attribute Time
# Processing sample 58 with attribute Released
# Processing sample 59 with attribute Song_Name
# Processing sample 59 with attribute Artist_Name
# Processing sample 59 with attribute Album_Name
# Processing sample 59 with attribute Genre
# Processing sample 59 with attribute Price
# Processing sample 59 with attribute CopyRight
# Processing sample 59 with attribute Time
# Processing sample 59 with attribute Released
# Processing sample 60 with attribute Song_Name
# Processing sample 60 with attribute Artist_Name
# Processing sample 60 with attribute Album_Name
# Processing sample 60 with attribute Genre
# Processing sample 60 with attribute Price
# Processing sample 60 with attribute CopyRight
# Processing sample 60 with attribute Time
# Processing sample 60 with attribute Released
# Processing sample 61 with attribute Song_Name
# Processing sample 61 with attribute Artist_Name
# Processing sample 61 with attribute Album_Name
# Processing sample 61 with attribute Genre
# Processing sample 61 with attribute Price
# Processing sample 61 with attribute CopyRight
# Processing sample 61 with attribute Time
# Processing sample 61 with attribute Released
# Processing sample 62 with attribute Song_Name
# Processing sample 62 with attribute Artist_Name
# Processing sample 62 with attribute Album_Name
# Processing sample 62 with attribute Genre
# Processing sample 62 with attribute Price
# Processing sample 62 with attribute CopyRight
# Processing sample 62 with attribute Time
# Processing sample 62 with attribute Released
# Processing sample 63 with attribute Song_Name
# Processing sample 63 with attribute Artist_Name
# Processing sample 63 with attribute Album_Name
# Processing sample 63 with attribute Genre
# Processing sample 63 with attribute Price
# Processing sample 63 with attribute CopyRight
# Processing sample 63 with attribute Time
# Processing sample 63 with attribute Released
# Processing sample 64 with attribute Song_Name
# Processing sample 64 with attribute Artist_Name
# Processing sample 64 with attribute Album_Name
# Processing sample 64 with attribute Genre
# Processing sample 64 with attribute Price
# Processing sample 64 with attribute CopyRight
# Processing sample 64 with attribute Time
# Processing sample 64 with attribute Released
# Processing sample 65 with attribute Song_Name
# Processing sample 65 with attribute Artist_Name
# Processing sample 65 with attribute Album_Name
# Processing sample 65 with attribute Genre
# Processing sample 65 with attribute Price
# Processing sample 65 with attribute CopyRight
# Processing sample 65 with attribute Time
# Processing sample 65 with attribute Released
# Processing sample 66 with attribute Song_Name
# Processing sample 66 with attribute Artist_Name
# Processing sample 66 with attribute Album_Name
# Processing sample 66 with attribute Genre
# Processing sample 66 with attribute Price
# Processing sample 66 with attribute CopyRight
# Processing sample 66 with attribute Time
# Processing sample 66 with attribute Released
# Processing sample 67 with attribute Song_Name
# Processing sample 67 with attribute Artist_Name
# Processing sample 67 with attribute Album_Name
# Processing sample 67 with attribute Genre
# Processing sample 67 with attribute Price
# Processing sample 67 with attribute CopyRight
# Processing sample 67 with attribute Time
# Processing sample 67 with attribute Released
# Processing sample 68 with attribute Song_Name
# Processing sample 68 with attribute Artist_Name
# Processing sample 68 with attribute Album_Name
# Processing sample 68 with attribute Genre
# Processing sample 68 with attribute Price
# Processing sample 68 with attribute CopyRight
# Processing sample 68 with attribute Time
# Processing sample 68 with attribute Released
# Processing sample 69 with attribute Song_Name
# Processing sample 69 with attribute Artist_Name
# Processing sample 69 with attribute Album_Name
# Processing sample 69 with attribute Genre
# Processing sample 69 with attribute Price
# Processing sample 69 with attribute CopyRight
# Processing sample 69 with attribute Time
# Processing sample 69 with attribute Released
# Processing sample 70 with attribute Song_Name
# Processing sample 70 with attribute Artist_Name
# Processing sample 70 with attribute Album_Name
# Processing sample 70 with attribute Genre
# Processing sample 70 with attribute Price
# Processing sample 70 with attribute CopyRight
# Processing sample 70 with attribute Time
# Processing sample 70 with attribute Released
# Processing sample 71 with attribute Song_Name
# Processing sample 71 with attribute Artist_Name
# Processing sample 71 with attribute Album_Name
# Processing sample 71 with attribute Genre
# Processing sample 71 with attribute Price
# Processing sample 71 with attribute CopyRight
# Processing sample 71 with attribute Time
# Processing sample 71 with attribute Released
# Processing sample 72 with attribute Song_Name
# Processing sample 72 with attribute Artist_Name
# Processing sample 72 with attribute Album_Name
# Processing sample 72 with attribute Genre
# Processing sample 72 with attribute Price
# Processing sample 72 with attribute CopyRight
# Processing sample 72 with attribute Time
# Processing sample 72 with attribute Released
# Processing sample 73 with attribute Song_Name
# Processing sample 73 with attribute Artist_Name
# Processing sample 73 with attribute Album_Name
# Processing sample 73 with attribute Genre
# Processing sample 73 with attribute Price
# Processing sample 73 with attribute CopyRight
# Processing sample 73 with attribute Time
# Processing sample 73 with attribute Released
# Processing sample 74 with attribute Song_Name
# Processing sample 74 with attribute Artist_Name
# Processing sample 74 with attribute Album_Name
# Processing sample 74 with attribute Genre
# Processing sample 74 with attribute Price
# Processing sample 74 with attribute CopyRight
# Processing sample 74 with attribute Time
# Processing sample 74 with attribute Released
# Processing sample 75 with attribute Song_Name
# Processing sample 75 with attribute Artist_Name
# Processing sample 75 with attribute Album_Name
# Processing sample 75 with attribute Genre
# Processing sample 75 with attribute Price
# Processing sample 75 with attribute CopyRight
# Processing sample 75 with attribute Time
# Processing sample 75 with attribute Released
# Processing sample 76 with attribute Song_Name
# Processing sample 76 with attribute Artist_Name
# Processing sample 76 with attribute Album_Name
# Processing sample 76 with attribute Genre
# Processing sample 76 with attribute Price
# Processing sample 76 with attribute CopyRight
# Processing sample 76 with attribute Time
# Processing sample 76 with attribute Released
# Processing sample 77 with attribute Song_Name
# Processing sample 77 with attribute Artist_Name
# Processing sample 77 with attribute Album_Name
# Processing sample 77 with attribute Genre
# Processing sample 77 with attribute Price
# Processing sample 77 with attribute CopyRight
# Processing sample 77 with attribute Time
# Processing sample 77 with attribute Released
# Processing sample 78 with attribute Song_Name
# Processing sample 78 with attribute Artist_Name
# Processing sample 78 with attribute Album_Name
# Processing sample 78 with attribute Genre
# Processing sample 78 with attribute Price
# Processing sample 78 with attribute CopyRight
# Processing sample 78 with attribute Time
# Processing sample 78 with attribute Released
# Processing sample 79 with attribute Song_Name
# Processing sample 79 with attribute Artist_Name
# Processing sample 79 with attribute Album_Name
# Processing sample 79 with attribute Genre
# Processing sample 79 with attribute Price
# Processing sample 79 with attribute CopyRight
# Processing sample 79 with attribute Time
# Processing sample 79 with attribute Released
# Processing sample 80 with attribute Song_Name
# Processing sample 80 with attribute Artist_Name
# Processing sample 80 with attribute Album_Name
# Processing sample 80 with attribute Genre
# Processing sample 80 with attribute Price
# Processing sample 80 with attribute CopyRight
# Processing sample 80 with attribute Time
# Processing sample 80 with attribute Released
# Processing sample 81 with attribute Song_Name
# Processing sample 81 with attribute Artist_Name
# Processing sample 81 with attribute Album_Name
# Processing sample 81 with attribute Genre
# Processing sample 81 with attribute Price
# Processing sample 81 with attribute CopyRight
# Processing sample 81 with attribute Time
# Processing sample 81 with attribute Released
# Processing sample 82 with attribute Song_Name
# Processing sample 82 with attribute Artist_Name
# Processing sample 82 with attribute Album_Name
# Processing sample 82 with attribute Genre
# Processing sample 82 with attribute Price
# Processing sample 82 with attribute CopyRight
# Processing sample 82 with attribute Time
# Processing sample 82 with attribute Released
# Processing sample 83 with attribute Song_Name
# Processing sample 83 with attribute Artist_Name
# Processing sample 83 with attribute Album_Name
# Processing sample 83 with attribute Genre
# Processing sample 83 with attribute Price
# Processing sample 83 with attribute CopyRight
# Processing sample 83 with attribute Time
# Processing sample 83 with attribute Released
# Processing sample 84 with attribute Song_Name
# Processing sample 84 with attribute Artist_Name
# Processing sample 84 with attribute Album_Name
# Processing sample 84 with attribute Genre
# Processing sample 84 with attribute Price
# Processing sample 84 with attribute CopyRight
# Processing sample 84 with attribute Time
# Processing sample 84 with attribute Released
# Processing sample 85 with attribute Song_Name
# Processing sample 85 with attribute Artist_Name
# Processing sample 85 with attribute Album_Name
# Processing sample 85 with attribute Genre
# Processing sample 85 with attribute Price
# Processing sample 85 with attribute CopyRight
# Processing sample 85 with attribute Time
# Processing sample 85 with attribute Released
# Processing sample 86 with attribute Song_Name
# Processing sample 86 with attribute Artist_Name
# Processing sample 86 with attribute Album_Name
# Processing sample 86 with attribute Genre
# Processing sample 86 with attribute Price
# Processing sample 86 with attribute CopyRight
# Processing sample 86 with attribute Time
# Processing sample 86 with attribute Released
# Processing sample 87 with attribute Song_Name
# Processing sample 87 with attribute Artist_Name
# Processing sample 87 with attribute Album_Name
# Processing sample 87 with attribute Genre
# Processing sample 87 with attribute Price
# Processing sample 87 with attribute CopyRight
# Processing sample 87 with attribute Time
# Processing sample 87 with attribute Released
# Processing sample 88 with attribute Song_Name
# Processing sample 88 with attribute Artist_Name
# Processing sample 88 with attribute Album_Name
# Processing sample 88 with attribute Genre
# Processing sample 88 with attribute Price
# Processing sample 88 with attribute CopyRight
# Processing sample 88 with attribute Time
# Processing sample 88 with attribute Released
# Processing sample 89 with attribute Song_Name
# Processing sample 89 with attribute Artist_Name
# Processing sample 89 with attribute Album_Name
# Processing sample 89 with attribute Genre
# Processing sample 89 with attribute Price
# Processing sample 89 with attribute CopyRight
# Processing sample 89 with attribute Time
# Processing sample 89 with attribute Released
# Processing sample 90 with attribute Song_Name
# Processing sample 90 with attribute Artist_Name
# Processing sample 90 with attribute Album_Name
# Processing sample 90 with attribute Genre
# Processing sample 90 with attribute Price
# Processing sample 90 with attribute CopyRight
# Processing sample 90 with attribute Time
# Processing sample 90 with attribute Released
# Processing sample 91 with attribute Song_Name
# Processing sample 91 with attribute Artist_Name
# Processing sample 91 with attribute Album_Name
# Processing sample 91 with attribute Genre
# Processing sample 91 with attribute Price
# Processing sample 91 with attribute CopyRight
# Processing sample 91 with attribute Time
# Processing sample 91 with attribute Released
# Processing sample 92 with attribute Song_Name
# Processing sample 92 with attribute Artist_Name
# Processing sample 92 with attribute Album_Name
# Processing sample 92 with attribute Genre
# Processing sample 92 with attribute Price
# Processing sample 92 with attribute CopyRight
# Processing sample 92 with attribute Time
# Processing sample 92 with attribute Released
# Processing sample 93 with attribute Song_Name
# Processing sample 93 with attribute Artist_Name
# Processing sample 93 with attribute Album_Name
# Processing sample 93 with attribute Genre
# Processing sample 93 with attribute Price
# Processing sample 93 with attribute CopyRight
# Processing sample 93 with attribute Time
# Processing sample 93 with attribute Released
# Processing sample 94 with attribute Song_Name
# Processing sample 94 with attribute Artist_Name
# Processing sample 94 with attribute Album_Name
# Processing sample 94 with attribute Genre
# Processing sample 94 with attribute Price
# Processing sample 94 with attribute CopyRight
# Processing sample 94 with attribute Time
# Processing sample 94 with attribute Released
# Processing sample 95 with attribute Song_Name
# Processing sample 95 with attribute Artist_Name
# Processing sample 95 with attribute Album_Name
# Processing sample 95 with attribute Genre
# Processing sample 95 with attribute Price
# Processing sample 95 with attribute CopyRight
# Processing sample 95 with attribute Time
# Processing sample 95 with attribute Released
# Processing sample 96 with attribute Song_Name
# Processing sample 96 with attribute Artist_Name
# Processing sample 96 with attribute Album_Name
# Processing sample 96 with attribute Genre
# Processing sample 96 with attribute Price
# Processing sample 96 with attribute CopyRight
# Processing sample 96 with attribute Time
# Processing sample 96 with attribute Released
# Processing sample 97 with attribute Song_Name
# Processing sample 97 with attribute Artist_Name
# Processing sample 97 with attribute Album_Name
# Processing sample 97 with attribute Genre
# Processing sample 97 with attribute Price
# Processing sample 97 with attribute CopyRight
# Processing sample 97 with attribute Time
# Processing sample 97 with attribute Released
# Processing sample 98 with attribute Song_Name
# Processing sample 98 with attribute Artist_Name
# Processing sample 98 with attribute Album_Name
# Processing sample 98 with attribute Genre
# Processing sample 98 with attribute Price
# Processing sample 98 with attribute CopyRight
# Processing sample 98 with attribute Time
# Processing sample 98 with attribute Released
# Processing sample 99 with attribute Song_Name
# Processing sample 99 with attribute Artist_Name
# Processing sample 99 with attribute Album_Name
# Processing sample 99 with attribute Genre
# Processing sample 99 with attribute Price
# Processing sample 99 with attribute CopyRight
# Processing sample 99 with attribute Time
# Processing sample 99 with attribute Released
# Processing sample 100 with attribute Song_Name
# Processing sample 100 with attribute Artist_Name
# Processing sample 100 with attribute Album_Name
# Processing sample 100 with attribute Genre
# Processing sample 100 with attribute Price
# Processing sample 100 with attribute CopyRight
# Processing sample 100 with attribute Time
# Processing sample 100 with attribute Released
# Processing sample 101 with attribute Song_Name
# Processing sample 101 with attribute Artist_Name
# Processing sample 101 with attribute Album_Name
# Processing sample 101 with attribute Genre
# Processing sample 101 with attribute Price
# Processing sample 101 with attribute CopyRight
# Processing sample 101 with attribute Time
# Processing sample 101 with attribute Released
# Processing sample 102 with attribute Song_Name
# Processing sample 102 with attribute Artist_Name
# Processing sample 102 with attribute Album_Name
# Processing sample 102 with attribute Genre
# Processing sample 102 with attribute Price
# Processing sample 102 with attribute CopyRight
# Processing sample 102 with attribute Time
# Processing sample 102 with attribute Released
# Processing sample 103 with attribute Song_Name
# Processing sample 103 with attribute Artist_Name
# Processing sample 103 with attribute Album_Name
# Processing sample 103 with attribute Genre
# Processing sample 103 with attribute Price
# Processing sample 103 with attribute CopyRight
# Processing sample 103 with attribute Time
# Processing sample 103 with attribute Released
# Processing sample 104 with attribute Song_Name
# Processing sample 104 with attribute Artist_Name
# Processing sample 104 with attribute Album_Name
# Processing sample 104 with attribute Genre
# Processing sample 104 with attribute Price
# Processing sample 104 with attribute CopyRight
# Processing sample 104 with attribute Time
# Processing sample 104 with attribute Released
# Processing sample 105 with attribute Song_Name
# Processing sample 105 with attribute Artist_Name
# Processing sample 105 with attribute Album_Name
# Processing sample 105 with attribute Genre
# Processing sample 105 with attribute Price
# Processing sample 105 with attribute CopyRight
# Processing sample 105 with attribute Time
# Processing sample 105 with attribute Released
# Processing sample 106 with attribute Song_Name
# Processing sample 106 with attribute Artist_Name
# Processing sample 106 with attribute Album_Name
# Processing sample 106 with attribute Genre
# Processing sample 106 with attribute Price
# Processing sample 106 with attribute CopyRight
# Processing sample 106 with attribute Time
# Processing sample 106 with attribute Released
# Processing sample 107 with attribute Song_Name
# Processing sample 107 with attribute Artist_Name
# Processing sample 107 with attribute Album_Name
# Processing sample 107 with attribute Genre
# Processing sample 107 with attribute Price
# Processing sample 107 with attribute CopyRight
# Processing sample 107 with attribute Time
# Processing sample 107 with attribute Released
# Processing sample 108 with attribute Song_Name
# Processing sample 108 with attribute Artist_Name
# Processing sample 108 with attribute Album_Name
# Processing sample 108 with attribute Genre
# Processing sample 108 with attribute Price
# Processing sample 108 with attribute CopyRight
# Processing sample 108 with attribute Time
# Processing sample 108 with attribute Released
# Processing sample 109 with attribute Song_Name
# Processing sample 109 with attribute Artist_Name
# Processing sample 109 with attribute Album_Name
# Processing sample 109 with attribute Genre
# Processing sample 109 with attribute Price
# Processing sample 109 with attribute CopyRight
# Processing sample 109 with attribute Time
# Processing sample 109 with attribute Released
# Processing sample 110 with attribute Song_Name
# Processing sample 110 with attribute Artist_Name
# Processing sample 110 with attribute Album_Name
# Processing sample 110 with attribute Genre
# Processing sample 110 with attribute Price
# Processing sample 110 with attribute CopyRight
# Processing sample 110 with attribute Time
# Processing sample 110 with attribute Released
# Processing sample 111 with attribute Song_Name
# Processing sample 111 with attribute Artist_Name
# Processing sample 111 with attribute Album_Name
# Processing sample 111 with attribute Genre
# Processing sample 111 with attribute Price
# Processing sample 111 with attribute CopyRight
# Processing sample 111 with attribute Time
# Processing sample 111 with attribute Released
# Processing sample 112 with attribute Song_Name
# Processing sample 112 with attribute Artist_Name
# Processing sample 112 with attribute Album_Name
# Processing sample 112 with attribute Genre
# Processing sample 112 with attribute Price
# Processing sample 112 with attribute CopyRight
# Processing sample 112 with attribute Time
# Processing sample 112 with attribute Released
# Processing sample 113 with attribute Song_Name
# Processing sample 113 with attribute Artist_Name
# Processing sample 113 with attribute Album_Name
# Processing sample 113 with attribute Genre
# Processing sample 113 with attribute Price
# Processing sample 113 with attribute CopyRight
# Processing sample 113 with attribute Time
# Processing sample 113 with attribute Released
# Processing sample 114 with attribute Song_Name
# Processing sample 114 with attribute Artist_Name
# Processing sample 114 with attribute Album_Name
# Processing sample 114 with attribute Genre
# Processing sample 114 with attribute Price
# Processing sample 114 with attribute CopyRight
# Processing sample 114 with attribute Time
# Processing sample 114 with attribute Released
# Processing sample 115 with attribute Song_Name
# Processing sample 115 with attribute Artist_Name
# Processing sample 115 with attribute Album_Name
# Processing sample 115 with attribute Genre
# Processing sample 115 with attribute Price
# Processing sample 115 with attribute CopyRight
# Processing sample 115 with attribute Time
# Processing sample 115 with attribute Released
# Processing sample 116 with attribute Song_Name
# Processing sample 116 with attribute Artist_Name
# Processing sample 116 with attribute Album_Name
# Processing sample 116 with attribute Genre
# Processing sample 116 with attribute Price
# Processing sample 116 with attribute CopyRight
# Processing sample 116 with attribute Time
# Processing sample 116 with attribute Released
# Processing sample 117 with attribute Song_Name
# Processing sample 117 with attribute Artist_Name
# Processing sample 117 with attribute Album_Name
# Processing sample 117 with attribute Genre
# Processing sample 117 with attribute Price
# Processing sample 117 with attribute CopyRight
# Processing sample 117 with attribute Time
# Processing sample 117 with attribute Released
# Processing sample 118 with attribute Song_Name
# Processing sample 118 with attribute Artist_Name
# Processing sample 118 with attribute Album_Name
# Processing sample 118 with attribute Genre
# Processing sample 118 with attribute Price
# Processing sample 118 with attribute CopyRight
# Processing sample 118 with attribute Time
# Processing sample 118 with attribute Released
# Processing sample 119 with attribute Song_Name
# Processing sample 119 with attribute Artist_Name
# Processing sample 119 with attribute Album_Name
# Processing sample 119 with attribute Genre
# Processing sample 119 with attribute Price
# Processing sample 119 with attribute CopyRight
# Processing sample 119 with attribute Time
# Processing sample 119 with attribute Released
# Processing sample 120 with attribute Song_Name
# Processing sample 120 with attribute Artist_Name
# Processing sample 120 with attribute Album_Name
# Processing sample 120 with attribute Genre
# Processing sample 120 with attribute Price
# Processing sample 120 with attribute CopyRight
# Processing sample 120 with attribute Time
# Processing sample 120 with attribute Released
# Processing sample 121 with attribute Song_Name
# Processing sample 121 with attribute Artist_Name
# Processing sample 121 with attribute Album_Name
# Processing sample 121 with attribute Genre
# Processing sample 121 with attribute Price
# Processing sample 121 with attribute CopyRight
# Processing sample 121 with attribute Time
# Processing sample 121 with attribute Released
# Processing sample 122 with attribute Song_Name
# Processing sample 122 with attribute Artist_Name
# Processing sample 122 with attribute Album_Name
# Processing sample 122 with attribute Genre
# Processing sample 122 with attribute Price
# Processing sample 122 with attribute CopyRight
# Processing sample 122 with attribute Time
# Processing sample 122 with attribute Released
# Processing sample 123 with attribute Song_Name
# Processing sample 123 with attribute Artist_Name
# Processing sample 123 with attribute Album_Name
# Processing sample 123 with attribute Genre
# Processing sample 123 with attribute Price
# Processing sample 123 with attribute CopyRight
# Processing sample 123 with attribute Time
# Processing sample 123 with attribute Released
# Processing sample 124 with attribute Song_Name
# Processing sample 124 with attribute Artist_Name
# Processing sample 124 with attribute Album_Name
# Processing sample 124 with attribute Genre
# Processing sample 124 with attribute Price
# Processing sample 124 with attribute CopyRight
# Processing sample 124 with attribute Time
# Processing sample 124 with attribute Released
# Processing sample 125 with attribute Song_Name
# Processing sample 125 with attribute Artist_Name
# Processing sample 125 with attribute Album_Name
# Processing sample 125 with attribute Genre
# Processing sample 125 with attribute Price
# Processing sample 125 with attribute CopyRight
# Processing sample 125 with attribute Time
# Processing sample 125 with attribute Released
# Processing sample 126 with attribute Song_Name
# Processing sample 126 with attribute Artist_Name
# Processing sample 126 with attribute Album_Name
# Processing sample 126 with attribute Genre
# Processing sample 126 with attribute Price
# Processing sample 126 with attribute CopyRight
# Processing sample 126 with attribute Time
# Processing sample 126 with attribute Released
# Processing sample 127 with attribute Song_Name
# Processing sample 127 with attribute Artist_Name
# Processing sample 127 with attribute Album_Name
# Processing sample 127 with attribute Genre
# Processing sample 127 with attribute Price
# Processing sample 127 with attribute CopyRight
# Processing sample 127 with attribute Time
# Processing sample 127 with attribute Released
# Processing sample 128 with attribute Song_Name
# Processing sample 128 with attribute Artist_Name
# Processing sample 128 with attribute Album_Name
# Processing sample 128 with attribute Genre
# Processing sample 128 with attribute Price
# Processing sample 128 with attribute CopyRight
# Processing sample 128 with attribute Time
# Processing sample 128 with attribute Released
# Processing sample 129 with attribute Song_Name
# Processing sample 129 with attribute Artist_Name
# Processing sample 129 with attribute Album_Name
# Processing sample 129 with attribute Genre
# Processing sample 129 with attribute Price
# Processing sample 129 with attribute CopyRight
# Processing sample 129 with attribute Time
# Processing sample 129 with attribute Released
# Processing sample 130 with attribute Song_Name
# Processing sample 130 with attribute Artist_Name
# Processing sample 130 with attribute Album_Name
# Processing sample 130 with attribute Genre
# Processing sample 130 with attribute Price
# Processing sample 130 with attribute CopyRight
# Processing sample 130 with attribute Time
# Processing sample 130 with attribute Released
# Processing sample 131 with attribute Song_Name
# Processing sample 131 with attribute Artist_Name
# Processing sample 131 with attribute Album_Name
# Processing sample 131 with attribute Genre
# Processing sample 131 with attribute Price
# Processing sample 131 with attribute CopyRight
# Processing sample 131 with attribute Time
# Processing sample 131 with attribute Released
# Processing sample 132 with attribute Song_Name
# Processing sample 132 with attribute Artist_Name
# Processing sample 132 with attribute Album_Name
# Processing sample 132 with attribute Genre
# Processing sample 132 with attribute Price
# Processing sample 132 with attribute CopyRight
# Processing sample 132 with attribute Time
# Processing sample 132 with attribute Released
# Processing sample 133 with attribute Song_Name
# Processing sample 133 with attribute Artist_Name
# Processing sample 133 with attribute Album_Name
# Processing sample 133 with attribute Genre
# Processing sample 133 with attribute Price
# Processing sample 133 with attribute CopyRight
# Processing sample 133 with attribute Time
# ...
# Processing sample 363 with attribute Album_Name
# Processing sample 363 with attribute Genre
# Processing sample 363 with attribute Price
# Processing sample 363 with attribute CopyRight
# Processing sample 363 with attribute Time
# Processing sample 363 with attribute Released
# Processing sample 364 with attribute Song_Name
# Processing sample 364 with attribute Artist_Name
# Processing sample 364 with attribute Album_Name
# Processing sample 364 with attribute Genre
# Processing sample 364 with attribute Price
# Processing sample 364 with attribute CopyRight
# Processing sample 364 with attribute Time
# Processing sample 364 with attribute Released
# Processing sample 365 with attribute Song_Name
# Processing sample 365 with attribute Artist_Name
# Processing sample 365 with attribute Album_Name
# Processing sample 365 with attribute Genre
# Processing sample 365 with attribute Price
# Processing sample 365 with attribute CopyRight
# Processing sample 365 with attribute Time
# Processing sample 365 with attribute Released
# Processing sample 366 with attribute Song_Name
# Processing sample 366 with attribute Artist_Name
# Processing sample 366 with attribute Album_Name
# Processing sample 366 with attribute Genre
# Processing sample 366 with attribute Price
# Processing sample 366 with attribute CopyRight
# Processing sample 366 with attribute Time
# Processing sample 366 with attribute Released
# Processing sample 367 with attribute Song_Name
# Processing sample 367 with attribute Artist_Name
# Processing sample 367 with attribute Album_Name
# Processing sample 367 with attribute Genre
# Processing sample 367 with attribute Price
# Processing sample 367 with attribute CopyRight
# Processing sample 367 with attribute Time
# Processing sample 367 with attribute Released
# Processing sample 368 with attribute Song_Name
# Processing sample 368 with attribute Artist_Name
# Processing sample 368 with attribute Album_Name
# Processing sample 368 with attribute Genre
# Processing sample 368 with attribute Price
# Processing sample 368 with attribute CopyRight
# Processing sample 368 with attribute Time
# Processing sample 368 with attribute Released
# Processing sample 369 with attribute Song_Name
# Processing sample 369 with attribute Artist_Name
# Processing sample 369 with attribute Album_Name
# Processing sample 369 with attribute Genre
# Processing sample 369 with attribute Price
# Processing sample 369 with attribute CopyRight
# Processing sample 369 with attribute Time
# Processing sample 369 with attribute Released
# Processing sample 370 with attribute Song_Name
# Processing sample 370 with attribute Artist_Name
# Processing sample 370 with attribute Album_Name
# Processing sample 370 with attribute Genre
# Processing sample 370 with attribute Price
# Processing sample 370 with attribute CopyRight
# Processing sample 370 with attribute Time
# Processing sample 370 with attribute Released
# Processing sample 371 with attribute Song_Name
# Processing sample 371 with attribute Artist_Name
# Processing sample 371 with attribute Album_Name
# Processing sample 371 with attribute Genre
# Processing sample 371 with attribute Price
# Processing sample 371 with attribute CopyRight
# Processing sample 371 with attribute Time
# Processing sample 371 with attribute Released
# Processing sample 372 with attribute Song_Name
# Processing sample 372 with attribute Artist_Name
# Processing sample 372 with attribute Album_Name
# Processing sample 372 with attribute Genre
# Processing sample 372 with attribute Price
# Processing sample 372 with attribute CopyRight
# Processing sample 372 with attribute Time
# Processing sample 372 with attribute Released
# Processing sample 373 with attribute Song_Name
# Processing sample 373 with attribute Artist_Name
# Processing sample 373 with attribute Album_Name
# Processing sample 373 with attribute Genre
# Processing sample 373 with attribute Price
# Processing sample 373 with attribute CopyRight
# Processing sample 373 with attribute Time
# Processing sample 373 with attribute Released
# Processing sample 374 with attribute Song_Name
# Processing sample 374 with attribute Artist_Name
# Processing sample 374 with attribute Album_Name
# Processing sample 374 with attribute Genre
# Processing sample 374 with attribute Price
# Processing sample 374 with attribute CopyRight
# Processing sample 374 with attribute Time
# Processing sample 374 with attribute Released
# Processing sample 375 with attribute Song_Name
# Processing sample 375 with attribute Artist_Name
# Processing sample 375 with attribute Album_Name
# Processing sample 375 with attribute Genre
# Processing sample 375 with attribute Price
# Processing sample 375 with attribute CopyRight
# Processing sample 375 with attribute Time
# Processing sample 375 with attribute Released
# Processing sample 376 with attribute Song_Name
# Processing sample 376 with attribute Artist_Name
# Processing sample 376 with attribute Album_Name
# Processing sample 376 with attribute Genre
# Processing sample 376 with attribute Price
# Processing sample 376 with attribute CopyRight
# Processing sample 376 with attribute Time
# Processing sample 376 with attribute Released
# Processing sample 377 with attribute Song_Name
# Processing sample 377 with attribute Artist_Name
# Processing sample 377 with attribute Album_Name
# Processing sample 377 with attribute Genre
# Processing sample 377 with attribute Price
# Processing sample 377 with attribute CopyRight
# Processing sample 377 with attribute Time
# Processing sample 377 with attribute Released
# Processing sample 378 with attribute Song_Name
# Processing sample 378 with attribute Artist_Name
# Processing sample 378 with attribute Album_Name
# Processing sample 378 with attribute Genre
# Processing sample 378 with attribute Price
# Processing sample 378 with attribute CopyRight
# Processing sample 378 with attribute Time
# Processing sample 378 with attribute Released
# Processing sample 379 with attribute Song_Name
# Processing sample 379 with attribute Artist_Name
# Processing sample 379 with attribute Album_Name
# Processing sample 379 with attribute Genre
# Processing sample 379 with attribute Price
# Processing sample 379 with attribute CopyRight
# Processing sample 379 with attribute Time
# Processing sample 379 with attribute Released
# Processing sample 380 with attribute Song_Name
# Processing sample 380 with attribute Artist_Name
# Processing sample 380 with attribute Album_Name
# Processing sample 380 with attribute Genre
# Processing sample 380 with attribute Price
# Processing sample 380 with attribute CopyRight
# Processing sample 380 with attribute Time
# Processing sample 380 with attribute Released
# Processing sample 381 with attribute Song_Name
# Processing sample 381 with attribute Artist_Name
# Processing sample 381 with attribute Album_Name
# Processing sample 381 with attribute Genre
# Processing sample 381 with attribute Price
# Processing sample 381 with attribute CopyRight
# Processing sample 381 with attribute Time
# Processing sample 381 with attribute Released
# Processing sample 382 with attribute Song_Name
# Processing sample 382 with attribute Artist_Name
# Processing sample 382 with attribute Album_Name
# Processing sample 382 with attribute Genre
# Processing sample 382 with attribute Price
# Processing sample 382 with attribute CopyRight
# Processing sample 382 with attribute Time
# Processing sample 382 with attribute Released
# Processing sample 383 with attribute Song_Name
# Processing sample 383 with attribute Artist_Name
# Processing sample 383 with attribute Album_Name
# Processing sample 383 with attribute Genre
# Processing sample 383 with attribute Price
# Processing sample 383 with attribute CopyRight
# Processing sample 383 with attribute Time
# Processing sample 383 with attribute Released
# Processing sample 384 with attribute Song_Name
# Processing sample 384 with attribute Artist_Name
# Processing sample 384 with attribute Album_Name
# Processing sample 384 with attribute Genre
# Processing sample 384 with attribute Price
# Processing sample 384 with attribute CopyRight
# Processing sample 384 with attribute Time
# Processing sample 384 with attribute Released
# Processing sample 385 with attribute Song_Name
# Processing sample 385 with attribute Artist_Name
# Processing sample 385 with attribute Album_Name
# Processing sample 385 with attribute Genre
# Processing sample 385 with attribute Price
# Processing sample 385 with attribute CopyRight
# Processing sample 385 with attribute Time
# Processing sample 385 with attribute Released
# Processing sample 386 with attribute Song_Name
# Processing sample 386 with attribute Artist_Name
# Processing sample 386 with attribute Album_Name
# Processing sample 386 with attribute Genre
# Processing sample 386 with attribute Price
# Processing sample 386 with attribute CopyRight
# Processing sample 386 with attribute Time
# Processing sample 386 with attribute Released
# Processing sample 387 with attribute Song_Name
# Processing sample 387 with attribute Artist_Name
# Processing sample 387 with attribute Album_Name
# Processing sample 387 with attribute Genre
# Processing sample 387 with attribute Price
# Processing sample 387 with attribute CopyRight
# Processing sample 387 with attribute Time
# Processing sample 387 with attribute Released
# Processing sample 388 with attribute Song_Name
# Processing sample 388 with attribute Artist_Name
# Processing sample 388 with attribute Album_Name
# Processing sample 388 with attribute Genre
# Processing sample 388 with attribute Price
# Processing sample 388 with attribute CopyRight
# Processing sample 388 with attribute Time
# Processing sample 388 with attribute Released
# Processing sample 389 with attribute Song_Name
# Processing sample 389 with attribute Artist_Name
# Processing sample 389 with attribute Album_Name
# Processing sample 389 with attribute Genre
# Processing sample 389 with attribute Price
# Processing sample 389 with attribute CopyRight
# Processing sample 389 with attribute Time
# Processing sample 389 with attribute Released
# Processing sample 390 with attribute Song_Name
# Processing sample 390 with attribute Artist_Name
# Processing sample 390 with attribute Album_Name
# Processing sample 390 with attribute Genre
# Processing sample 390 with attribute Price
# Processing sample 390 with attribute CopyRight
# Processing sample 390 with attribute Time
# Processing sample 390 with attribute Released
# Processing sample 391 with attribute Song_Name
# Processing sample 391 with attribute Artist_Name
# Processing sample 391 with attribute Album_Name
# Processing sample 391 with attribute Genre
# Processing sample 391 with attribute Price
# Processing sample 391 with attribute CopyRight
# Processing sample 391 with attribute Time
# Processing sample 391 with attribute Released
# Processing sample 392 with attribute Song_Name
# Processing sample 392 with attribute Artist_Name
# Processing sample 392 with attribute Album_Name
# Processing sample 392 with attribute Genre
# Processing sample 392 with attribute Price
# Processing sample 392 with attribute CopyRight
# Processing sample 392 with attribute Time
# Processing sample 392 with attribute Released
# Processing sample 393 with attribute Song_Name
# Processing sample 393 with attribute Artist_Name
# Processing sample 393 with attribute Album_Name
# Processing sample 393 with attribute Genre
# Processing sample 393 with attribute Price
# Processing sample 393 with attribute CopyRight
# Processing sample 393 with attribute Time
# Processing sample 393 with attribute Released
# Processing sample 394 with attribute Song_Name
# Processing sample 394 with attribute Artist_Name
# Processing sample 394 with attribute Album_Name
# Processing sample 394 with attribute Genre
# Processing sample 394 with attribute Price
# Processing sample 394 with attribute CopyRight
# Processing sample 394 with attribute Time
# Processing sample 394 with attribute Released
# Processing sample 395 with attribute Song_Name
# Processing sample 395 with attribute Artist_Name
# Processing sample 395 with attribute Album_Name
# Processing sample 395 with attribute Genre
# Processing sample 395 with attribute Price
# Processing sample 395 with attribute CopyRight
# Processing sample 395 with attribute Time
# Processing sample 395 with attribute Released
# Processing sample 396 with attribute Song_Name
# Processing sample 396 with attribute Artist_Name
# Processing sample 396 with attribute Album_Name
# Processing sample 396 with attribute Genre
# Processing sample 396 with attribute Price
# Processing sample 396 with attribute CopyRight
# Processing sample 396 with attribute Time
# Processing sample 396 with attribute Released
# Processing sample 397 with attribute Song_Name
# Processing sample 397 with attribute Artist_Name
# Processing sample 397 with attribute Album_Name
# Processing sample 397 with attribute Genre
# Processing sample 397 with attribute Price
# Processing sample 397 with attribute CopyRight
# Processing sample 397 with attribute Time
# Processing sample 397 with attribute Released
# Processing sample 398 with attribute Song_Name
# Processing sample 398 with attribute Artist_Name
# Processing sample 398 with attribute Album_Name
# Processing sample 398 with attribute Genre
# Processing sample 398 with attribute Price
# Processing sample 398 with attribute CopyRight
# Processing sample 398 with attribute Time
# Processing sample 398 with attribute Released
# Processing sample 399 with attribute Song_Name
# Processing sample 399 with attribute Artist_Name
# Processing sample 399 with attribute Album_Name
# Processing sample 399 with attribute Genre
# Processing sample 399 with attribute Price
# Processing sample 399 with attribute CopyRight
# Processing sample 399 with attribute Time
# Processing sample 399 with attribute Released
# Processing sample 400 with attribute Song_Name
# Processing sample 400 with attribute Artist_Name
# Processing sample 400 with attribute Album_Name
# Processing sample 400 with attribute Genre
# Processing sample 400 with attribute Price
# Processing sample 400 with attribute CopyRight
# Processing sample 400 with attribute Time
# Processing sample 400 with attribute Released
# Processing sample 401 with attribute Song_Name
# Processing sample 401 with attribute Artist_Name
# Processing sample 401 with attribute Album_Name
# Processing sample 401 with attribute Genre
# Processing sample 401 with attribute Price
# Processing sample 401 with attribute CopyRight
# Processing sample 401 with attribute Time
# Processing sample 401 with attribute Released
# Processing sample 402 with attribute Song_Name
# Processing sample 402 with attribute Artist_Name
# Processing sample 402 with attribute Album_Name
# Processing sample 402 with attribute Genre
# Processing sample 402 with attribute Price
# Processing sample 402 with attribute CopyRight
# Processing sample 402 with attribute Time
# Processing sample 402 with attribute Released
# Processing sample 403 with attribute Song_Name
# Processing sample 403 with attribute Artist_Name
# Processing sample 403 with attribute Album_Name
# Processing sample 403 with attribute Genre
# Processing sample 403 with attribute Price
# Processing sample 403 with attribute CopyRight
# Processing sample 403 with attribute Time
# Processing sample 403 with attribute Released
# Processing sample 404 with attribute Song_Name
# Processing sample 404 with attribute Artist_Name
# Processing sample 404 with attribute Album_Name
# Processing sample 404 with attribute Genre
# Processing sample 404 with attribute Price
# Processing sample 404 with attribute CopyRight
# Processing sample 404 with attribute Time
# Processing sample 404 with attribute Released
# Processing sample 405 with attribute Song_Name
# Processing sample 405 with attribute Artist_Name
# Processing sample 405 with attribute Album_Name
# Processing sample 405 with attribute Genre
# Processing sample 405 with attribute Price
# Processing sample 405 with attribute CopyRight
# Processing sample 405 with attribute Time
# Processing sample 405 with attribute Released
# Processing sample 406 with attribute Song_Name
# Processing sample 406 with attribute Artist_Name
# Processing sample 406 with attribute Album_Name
# Processing sample 406 with attribute Genre
# Processing sample 406 with attribute Price
# Processing sample 406 with attribute CopyRight
# Processing sample 406 with attribute Time
# Processing sample 406 with attribute Released

# %%
ri_norms_negative_samples = []
for ri_list in negatives_ri_matrix:
    ri_norms_negative_samples.append(list(map(lambda x:torch.norm(x).data[0],ri_list)))

# %%
import pandas as pd
variation_df = pd.DataFrame(data= ri_norms_negative_samples,columns=attributes)

# %%
columns = list(variation_df)
sum_ri = {}
for col in columns:
    sum_ri[col] = variation_df[col].sum()

# %%
sum_ri
# Out:
# {'Song_Name': 2987.083234190941,
#  'Artist_Name': 6260.2585825920105,
#  'Album_Name': 3704.05709028244,
#  'Genre': 6413.990332603455,
#  'Price': 3389.5156993865967,
#  'CopyRight': 6076.511769771576,
#  'Time': 2636.632802248001,
#  'Released': 6247.0441999435425}

# %%
variation_df.to_csv('experiments-results/negative_samples_ri.csv',index=False)

# %% [markdown]
# ## Positive samples analisys

# %%
attribute_lenght= len(attributes)
positive_samples_ri_matrix = []
current_sample = 0

for batch in positive_classifier_inputs:
    for index in range(len(batch)):
        current_sample_ris = []
        for j,attribute in enumerate(attributes):
            print('Processing sample {} with attribute {}'.format(current_sample,attribute))
            it,variation = find_smallest_variation_to_change(hybrid_model_numericencoding.classifier,batch,index,j,0)
            current_sample_ris.append(variation)
        positive_samples_ri_matrix.append(current_sample_ris)
        current_sample+=1
# Out:
# Processing sample 0 with attribute Song_Name
# Processing sample 0 with attribute Artist_Name
# Processing sample 0 with attribute Album_Name
# Processing sample 0 with attribute Genre
# Processing sample 0 with attribute Price
# Processing sample 0 with attribute CopyRight
# Processing sample 0 with attribute Time
# Processing sample 0 with attribute Released
# Processing sample 1 with attribute Song_Name
# Processing sample 1 with attribute Artist_Name
# Processing sample 1 with attribute Album_Name
# Processing sample 1 with attribute Genre
# Processing sample 1 with attribute Price
# Processing sample 1 with attribute CopyRight
# Processing sample 1 with attribute Time
# Processing sample 1 with attribute Released
# Processing sample 2 with attribute Song_Name
# Processing sample 2 with attribute Artist_Name
# Processing sample 2 with attribute Album_Name
# Processing sample 2 with attribute Genre
# Processing sample 2 with attribute Price
# Processing sample 2 with attribute CopyRight
# Processing sample 2 with attribute Time
# Processing sample 2 with attribute Released
# Processing sample 3 with attribute Song_Name
# Processing sample 3 with attribute Artist_Name
# Processing sample 3 with attribute Album_Name
# Processing sample 3 with attribute Genre
# Processing sample 3 with attribute Price
# Processing sample 3 with attribute CopyRight
# Processing sample 3 with attribute Time
# Processing sample 3 with attribute Released
# Processing sample 4 with attribute Song_Name
# Processing sample 4 with attribute Artist_Name
# Processing sample 4 with attribute Album_Name
# Processing sample 4 with attribute Genre
# Processing sample 4 with attribute Price
# Processing sample 4 with attribute CopyRight
# Processing sample 4 with attribute Time
# Processing sample 4 with attribute Released
# Processing sample 5 with attribute Song_Name
# Processing sample 5 with attribute Artist_Name
# Processing sample 5 with attribute Album_Name
# Processing sample 5 with attribute Genre
# Processing sample 5 with attribute Price
# Processing sample 5 with attribute CopyRight
# Processing sample 5 with attribute Time
# Processing sample 5 with attribute Released
# Processing sample 6 with attribute Song_Name
# Processing sample 6 with attribute Artist_Name
# Processing sample 6 with attribute Album_Name
# Processing sample 6 with attribute Genre
# Processing sample 6 with attribute Price
# Processing sample 6 with attribute CopyRight
# Processing sample 6 with attribute Time
# Processing sample 6 with attribute Released
# Processing sample 7 with attribute Song_Name
# Processing sample 7 with attribute Artist_Name
# Processing sample 7 with attribute Album_Name
# Processing sample 7 with attribute Genre
# Processing sample 7 with attribute Price
# Processing sample 7 with attribute CopyRight
# Processing sample 7 with attribute Time
# Processing sample 7 with attribute Released
# Processing sample 8 with attribute Song_Name
# Processing sample 8 with attribute Artist_Name
# Processing sample 8 with attribute Album_Name
# Processing sample 8 with attribute Genre
# Processing sample 8 with attribute Price
# Processing sample 8 with attribute CopyRight
# Processing sample 8 with attribute Time
# Processing sample 8 with attribute Released
# Processing sample 9 with attribute Song_Name
# Processing sample 9 with attribute Artist_Name
# Processing sample 9 with attribute Album_Name
# Processing sample 9 with attribute Genre
# Processing sample 9 with attribute Price
# Processing sample 9 with attribute CopyRight
# Processing sample 9 with attribute Time
# Processing sample 9 with attribute Released
# Processing sample 10 with attribute Song_Name
# Processing sample 10 with attribute Artist_Name
# Processing sample 10 with attribute Album_Name
# Processing sample 10 with attribute Genre
# Processing sample 10 with attribute Price
# Processing sample 10 with attribute CopyRight
# Processing sample 10 with attribute Time
# Processing sample 10 with attribute Released
# Processing sample 11 with attribute Song_Name
# Processing sample 11 with attribute Artist_Name
# Processing sample 11 with attribute Album_Name
# Processing sample 11 with attribute Genre
# Processing sample 11 with attribute Price
# Processing sample 11 with attribute CopyRight
# Processing sample 11 with attribute Time
# Processing sample 11 with attribute Released
# Processing sample 12 with attribute Song_Name
# Processing sample 12 with attribute Artist_Name
# Processing sample 12 with attribute Album_Name
# Processing sample 12 with attribute Genre
# Processing sample 12 with attribute Price
# Processing sample 12 with attribute CopyRight
# Processing sample 12 with attribute Time
# Processing sample 12 with attribute Released
# Processing sample 13 with attribute Song_Name
# Processing sample 13 with attribute Artist_Name
# Processing sample 13 with attribute Album_Name
# Processing sample 13 with attribute Genre
# Processing sample 13 with attribute Price
# Processing sample 13 with attribute CopyRight
# Processing sample 13 with attribute Time
# Processing sample 13 with attribute Released
# Processing sample 14 with attribute Song_Name
# Processing sample 14 with attribute Artist_Name
# Processing sample 14 with attribute Album_Name
# Processing sample 14 with attribute Genre
# Processing sample 14 with attribute Price
# Processing sample 14 with attribute CopyRight
# Processing sample 14 with attribute Time
# Processing sample 14 with attribute Released
# Processing sample 15 with attribute Song_Name
# Processing sample 15 with attribute Artist_Name
# Processing sample 15 with attribute Album_Name
# Processing sample 15 with attribute Genre
# Processing sample 15 with attribute Price
# Processing sample 15 with attribute CopyRight
# Processing sample 15 with attribute Time
# Processing sample 15 with attribute Released
# Processing sample 16 with attribute Song_Name
# Processing sample 16 with attribute Artist_Name
# Processing sample 16 with attribute Album_Name
# Processing sample 16 with attribute Genre
# Processing sample 16 with attribute Price
# Processing sample 16 with attribute CopyRight
# Processing sample 16 with attribute Time
# Processing sample 16 with attribute Released
# Processing sample 17 with attribute Song_Name
# Processing sample 17 with attribute Artist_Name
# Processing sample 17 with attribute Album_Name
# Processing sample 17 with attribute Genre
# Processing sample 17 with attribute Price
# Processing sample 17 with attribute CopyRight
# Processing sample 17 with attribute Time
# Processing sample 17 with attribute Released
# Processing sample 18 with attribute Song_Name
# Processing sample 18 with attribute Artist_Name
# Processing sample 18 with attribute Album_Name
# Processing sample 18 with attribute Genre
# Processing sample 18 with attribute Price
# Processing sample 18 with attribute CopyRight
# Processing sample 18 with attribute Time
# Processing sample 18 with attribute Released
# Processing sample 19 with attribute Song_Name
# Processing sample 19 with attribute Artist_Name
# Processing sample 19 with attribute Album_Name
# Processing sample 19 with attribute Genre
# Processing sample 19 with attribute Price
# Processing sample 19 with attribute CopyRight
# Processing sample 19 with attribute Time
# Processing sample 19 with attribute Released
# Processing sample 20 with attribute Song_Name
# Processing sample 20 with attribute Artist_Name
# Processing sample 20 with attribute Album_Name
# Processing sample 20 with attribute Genre
# Processing sample 20 with attribute Price
# Processing sample 20 with attribute CopyRight
# Processing sample 20 with attribute Time
# Processing sample 20 with attribute Released
# Processing sample 21 with attribute Song_Name
# Processing sample 21 with attribute Artist_Name
# Processing sample 21 with attribute Album_Name
# Processing sample 21 with attribute Genre
# Processing sample 21 with attribute Price
# Processing sample 21 with attribute CopyRight
# Processing sample 21 with attribute Time
# Processing sample 21 with attribute Released
# Processing sample 22 with attribute Song_Name
# Processing sample 22 with attribute Artist_Name
# Processing sample 22 with attribute Album_Name
# Processing sample 22 with attribute Genre
# Processing sample 22 with attribute Price
# Processing sample 22 with attribute CopyRight
# Processing sample 22 with attribute Time
# Processing sample 22 with attribute Released
# Processing sample 23 with attribute Song_Name
# Processing sample 23 with attribute Artist_Name
# Processing sample 23 with attribute Album_Name
# Processing sample 23 with attribute Genre
# Processing sample 23 with attribute Price
# Processing sample 23 with attribute CopyRight
# Processing sample 23 with attribute Time
# Processing sample 23 with attribute Released
# Processing sample 24 with attribute Song_Name
# Processing sample 24 with attribute Artist_Name
# Processing sample 24 with attribute Album_Name
# Processing sample 24 with attribute Genre
# Processing sample 24 with attribute Price
# Processing sample 24 with attribute CopyRight
# Processing sample 24 with attribute Time
# Processing sample 24 with attribute Released
# Processing sample 25 with attribute Song_Name
# Processing sample 25 with attribute Artist_Name
# Processing sample 25 with attribute Album_Name
# Processing sample 25 with attribute Genre
# Processing sample 25 with attribute Price
# Processing sample 25 with attribute CopyRight
# Processing sample 25 with attribute Time
# Processing sample 25 with attribute Released
# Processing sample 26 with attribute Song_Name
# Processing sample 26 with attribute Artist_Name
# Processing sample 26 with attribute Album_Name
# Processing sample 26 with attribute Genre
# Processing sample 26 with attribute Price
# Processing sample 26 with attribute CopyRight
# Processing sample 26 with attribute Time
# Processing sample 26 with attribute Released
# Processing sample 27 with attribute Song_Name
# Processing sample 27 with attribute Artist_Name
# Processing sample 27 with attribute Album_Name
# Processing sample 27 with attribute Genre
# Processing sample 27 with attribute Price
# Processing sample 27 with attribute CopyRight
# Processing sample 27 with attribute Time
# Processing sample 27 with attribute Released
# Processing sample 28 with attribute Song_Name
# Processing sample 28 with attribute Artist_Name
# Processing sample 28 with attribute Album_Name
# Processing sample 28 with attribute Genre
# Processing sample 28 with attribute Price
# Processing sample 28 with attribute CopyRight
# Processing sample 28 with attribute Time
# Processing sample 28 with attribute Released
# Processing sample 29 with attribute Song_Name
# Processing sample 29 with attribute Artist_Name
# Processing sample 29 with attribute Album_Name
# Processing sample 29 with attribute Genre
# Processing sample 29 with attribute Price
# Processing sample 29 with attribute CopyRight
# Processing sample 29 with attribute Time
# Processing sample 29 with attribute Released
# Processing sample 30 with attribute Song_Name
# Processing sample 30 with attribute Artist_Name
# Processing sample 30 with attribute Album_Name
# Processing sample 30 with attribute Genre
# Processing sample 30 with attribute Price
# Processing sample 30 with attribute CopyRight
# Processing sample 30 with attribute Time
# Processing sample 30 with attribute Released
# Processing sample 31 with attribute Song_Name
# Processing sample 31 with attribute Artist_Name
# Processing sample 31 with attribute Album_Name
# Processing sample 31 with attribute Genre
# Processing sample 31 with attribute Price
# Processing sample 31 with attribute CopyRight
# Processing sample 31 with attribute Time
# Processing sample 31 with attribute Released
# Processing sample 32 with attribute Song_Name
# Processing sample 32 with attribute Artist_Name
# Processing sample 32 with attribute Album_Name
# Processing sample 32 with attribute Genre
# Processing sample 32 with attribute Price
# Processing sample 32 with attribute CopyRight
# Processing sample 32 with attribute Time
# Processing sample 32 with attribute Released
# Processing sample 33 with attribute Song_Name
# Processing sample 33 with attribute Artist_Name
# Processing sample 33 with attribute Album_Name
# Processing sample 33 with attribute Genre
# Processing sample 33 with attribute Price
# Processing sample 33 with attribute CopyRight
# Processing sample 33 with attribute Time
# Processing sample 33 with attribute Released
# Processing sample 34 with attribute Song_Name
# Processing sample 34 with attribute Artist_Name
# Processing sample 34 with attribute Album_Name
# Processing sample 34 with attribute Genre
# Processing sample 34 with attribute Price
# Processing sample 34 with attribute CopyRight
# Processing sample 34 with attribute Time
# Processing sample 34 with attribute Released
# Processing sample 35 with attribute Song_Name
# Processing sample 35 with attribute Artist_Name
# Processing sample 35 with attribute Album_Name
# Processing sample 35 with attribute Genre
# Processing sample 35 with attribute Price
# Processing sample 35 with attribute CopyRight
# Processing sample 35 with attribute Time
# Processing sample 35 with attribute Released
# Processing sample 36 with attribute Song_Name
# Processing sample 36 with attribute Artist_Name
# Processing sample 36 with attribute Album_Name
# Processing sample 36 with attribute Genre
# Processing sample 36 with attribute Price
# Processing sample 36 with attribute CopyRight
# Processing sample 36 with attribute Time
# Processing sample 36 with attribute Released
# Processing sample 37 with attribute Song_Name
# Processing sample 37 with attribute Artist_Name
# Processing sample 37 with attribute Album_Name
# Processing sample 37 with attribute Genre
# Processing sample 37 with attribute Price
# Processing sample 37 with attribute CopyRight
# Processing sample 37 with attribute Time
# Processing sample 37 with attribute Released
# Processing sample 38 with attribute Song_Name
# Processing sample 38 with attribute Artist_Name
# Processing sample 38 with attribute Album_Name
# Processing sample 38 with attribute Genre
# Processing sample 38 with attribute Price
# Processing sample 38 with attribute CopyRight
# Processing sample 38 with attribute Time
# Processing sample 38 with attribute Released
# Processing sample 39 with attribute Song_Name
# Processing sample 39 with attribute Artist_Name
# Processing sample 39 with attribute Album_Name
# Processing sample 39 with attribute Genre
# Processing sample 39 with attribute Price
# Processing sample 39 with attribute CopyRight
# Processing sample 39 with attribute Time
# Processing sample 39 with attribute Released
# Processing sample 40 with attribute Song_Name
# Processing sample 40 with attribute Artist_Name
# Processing sample 40 with attribute Album_Name
# Processing sample 40 with attribute Genre
# Processing sample 40 with attribute Price
# Processing sample 40 with attribute CopyRight
# Processing sample 40 with attribute Time
# Processing sample 40 with attribute Released
# Processing sample 41 with attribute Song_Name
# Processing sample 41 with attribute Artist_Name
# Processing sample 41 with attribute Album_Name
# Processing sample 41 with attribute Genre
# Processing sample 41 with attribute Price
# Processing sample 41 with attribute CopyRight
# Processing sample 41 with attribute Time
# Processing sample 41 with attribute Released
# Processing sample 42 with attribute Song_Name
# Processing sample 42 with attribute Artist_Name
# Processing sample 42 with attribute Album_Name
# Processing sample 42 with attribute Genre
# Processing sample 42 with attribute Price
# Processing sample 42 with attribute CopyRight
# Processing sample 42 with attribute Time
# Processing sample 42 with attribute Released
# Processing sample 43 with attribute Song_Name
# Processing sample 43 with attribute Artist_Name
# Processing sample 43 with attribute Album_Name
# Processing sample 43 with attribute Genre
# Processing sample 43 with attribute Price
# Processing sample 43 with attribute CopyRight
# Processing sample 43 with attribute Time
# Processing sample 43 with attribute Released
# Processing sample 44 with attribute Song_Name
# Processing sample 44 with attribute Artist_Name
# Processing sample 44 with attribute Album_Name
# Processing sample 44 with attribute Genre
# Processing sample 44 with attribute Price
# Processing sample 44 with attribute CopyRight
# Processing sample 44 with attribute Time
# Processing sample 44 with attribute Released
# Processing sample 45 with attribute Song_Name
# Processing sample 45 with attribute Artist_Name
# Processing sample 45 with attribute Album_Name
# Processing sample 45 with attribute Genre
# Processing sample 45 with attribute Price
# Processing sample 45 with attribute CopyRight
# Processing sample 45 with attribute Time
# Processing sample 45 with attribute Released
# Processing sample 46 with attribute Song_Name
# Processing sample 46 with attribute Artist_Name
# Processing sample 46 with attribute Album_Name
# Processing sample 46 with attribute Genre
# Processing sample 46 with attribute Price
# Processing sample 46 with attribute CopyRight
# Processing sample 46 with attribute Time
# Processing sample 46 with attribute Released
# Processing sample 47 with attribute Song_Name
# Processing sample 47 with attribute Artist_Name
# Processing sample 47 with attribute Album_Name
# Processing sample 47 with attribute Genre
# Processing sample 47 with attribute Price
# Processing sample 47 with attribute CopyRight
# Processing sample 47 with attribute Time
# Processing sample 47 with attribute Released
# Processing sample 48 with attribute Song_Name
# Processing sample 48 with attribute Artist_Name
# Processing sample 48 with attribute Album_Name
# Processing sample 48 with attribute Genre
# Processing sample 48 with attribute Price
# Processing sample 48 with attribute CopyRight
# Processing sample 48 with attribute Time
# Processing sample 48 with attribute Released
# Processing sample 49 with attribute Song_Name
# Processing sample 49 with attribute Artist_Name
# Processing sample 49 with attribute Album_Name
# Processing sample 49 with attribute Genre
# Processing sample 49 with attribute Price
# Processing sample 49 with attribute CopyRight
# Processing sample 49 with attribute Time
# Processing sample 49 with attribute Released
# Processing sample 50 with attribute Song_Name
# Processing sample 50 with attribute Artist_Name
# Processing sample 50 with attribute Album_Name
# Processing sample 50 with attribute Genre
# Processing sample 50 with attribute Price
# Processing sample 50 with attribute CopyRight
# Processing sample 50 with attribute Time
# Processing sample 50 with attribute Released
# Processing sample 51 with attribute Song_Name
# Processing sample 51 with attribute Artist_Name
# Processing sample 51 with attribute Album_Name
# Processing sample 51 with attribute Genre
# Processing sample 51 with attribute Price
# Processing sample 51 with attribute CopyRight
# Processing sample 51 with attribute Time
# Processing sample 51 with attribute Released
# Processing sample 52 with attribute Song_Name
# Processing sample 52 with attribute Artist_Name
# Processing sample 52 with attribute Album_Name
# Processing sample 52 with attribute Genre
# Processing sample 52 with attribute Price
# Processing sample 52 with attribute CopyRight
# Processing sample 52 with attribute Time
# Processing sample 52 with attribute Released
# Processing sample 53 with attribute Song_Name
# Processing sample 53 with attribute Artist_Name
# Processing sample 53 with attribute Album_Name
# Processing sample 53 with attribute Genre
# Processing sample 53 with attribute Price
# Processing sample 53 with attribute CopyRight
# Processing sample 53 with attribute Time
# Processing sample 53 with attribute Released
# Processing sample 54 with attribute Song_Name
# Processing sample 54 with attribute Artist_Name
# Processing sample 54 with attribute Album_Name
# Processing sample 54 with attribute Genre
# Processing sample 54 with attribute Price
# Processing sample 54 with attribute CopyRight
# Processing sample 54 with attribute Time
# Processing sample 54 with attribute Released
# Processing sample 55 with attribute Song_Name
# Processing sample 55 with attribute Artist_Name
# Processing sample 55 with attribute Album_Name
# Processing sample 55 with attribute Genre
# Processing sample 55 with attribute Price
# Processing sample 55 with attribute CopyRight
# Processing sample 55 with attribute Time
# Processing sample 55 with attribute Released
# Processing sample 56 with attribute Song_Name
# Processing sample 56 with attribute Artist_Name
# Processing sample 56 with attribute Album_Name
# Processing sample 56 with attribute Genre
# Processing sample 56 with attribute Price
# Processing sample 56 with attribute CopyRight
# Processing sample 56 with attribute Time
# Processing sample 56 with attribute Released
# Processing sample 57 with attribute Song_Name
# Processing sample 57 with attribute Artist_Name
# Processing sample 57 with attribute Album_Name
# Processing sample 57 with attribute Genre
# Processing sample 57 with attribute Price
# Processing sample 57 with attribute CopyRight
# Processing sample 57 with attribute Time
# Processing sample 57 with attribute Released
# Processing sample 58 with attribute Song_Name
# Processing sample 58 with attribute Artist_Name
# Processing sample 58 with attribute Album_Name
# Processing sample 58 with attribute Genre
# Processing sample 58 with attribute Price
# Processing sample 58 with attribute CopyRight
# Processing sample 58 with attribute Time
# Processing sample 58 with attribute Released
# Processing sample 59 with attribute Song_Name
# Processing sample 59 with attribute Artist_Name
# Processing sample 59 with attribute Album_Name
# Processing sample 59 with attribute Genre
# Processing sample 59 with attribute Price
# Processing sample 59 with attribute CopyRight
# Processing sample 59 with attribute Time
# Processing sample 59 with attribute Released
# Processing sample 60 with attribute Song_Name
# Processing sample 60 with attribute Artist_Name
# Processing sample 60 with attribute Album_Name
# Processing sample 60 with attribute Genre
# Processing sample 60 with attribute Price
# Processing sample 60 with attribute CopyRight
# Processing sample 60 with attribute Time
# Processing sample 60 with attribute Released
# Processing sample 61 with attribute Song_Name
# Processing sample 61 with attribute Artist_Name
# Processing sample 61 with attribute Album_Name
# Processing sample 61 with attribute Genre
# Processing sample 61 with attribute Price
# Processing sample 61 with attribute CopyRight
# Processing sample 61 with attribute Time
# Processing sample 61 with attribute Released
# Processing sample 62 with attribute Song_Name
# Processing sample 62 with attribute Artist_Name
# Processing sample 62 with attribute Album_Name
# Processing sample 62 with attribute Genre
# Processing sample 62 with attribute Price
# Processing sample 62 with attribute CopyRight
# Processing sample 62 with attribute Time
# Processing sample 62 with attribute Released
# Processing sample 63 with attribute Song_Name
# Processing sample 63 with attribute Artist_Name
# Processing sample 63 with attribute Album_Name
# Processing sample 63 with attribute Genre
# Processing sample 63 with attribute Price
# Processing sample 63 with attribute CopyRight
# Processing sample 63 with attribute Time
# Processing sample 63 with attribute Released
# Processing sample 64 with attribute Song_Name
# Processing sample 64 with attribute Artist_Name
# Processing sample 64 with attribute Album_Name
# Processing sample 64 with attribute Genre
# Processing sample 64 with attribute Price
# Processing sample 64 with attribute CopyRight
# Processing sample 64 with attribute Time
# Processing sample 64 with attribute Released
# Processing sample 65 with attribute Song_Name
# Processing sample 65 with attribute Artist_Name
# Processing sample 65 with attribute Album_Name
# Processing sample 65 with attribute Genre
# Processing sample 65 with attribute Price
# Processing sample 65 with attribute CopyRight
# Processing sample 65 with attribute Time
# Processing sample 65 with attribute Released
# Processing sample 66 with attribute Song_Name
# Processing sample 66 with attribute Artist_Name
# Processing sample 66 with attribute Album_Name
# Processing sample 66 with attribute Genre
# Processing sample 66 with attribute Price
# Processing sample 66 with attribute CopyRight
# Processing sample 66 with attribute Time
# Processing sample 66 with attribute Released
# Processing sample 67 with attribute Song_Name
# Processing sample 67 with attribute Artist_Name
# Processing sample 67 with attribute Album_Name
# Processing sample 67 with attribute Genre
# Processing sample 67 with attribute Price
# Processing sample 67 with attribute CopyRight
# Processing sample 67 with attribute Time
# Processing sample 67 with attribute Released
# Processing sample 68 with attribute Song_Name
# Processing sample 68 with attribute Artist_Name
# Processing sample 68 with attribute Album_Name
# Processing sample 68 with attribute Genre
# Processing sample 68 with attribute Price
# Processing sample 68 with attribute CopyRight
# Processing sample 68 with attribute Time
# Processing sample 68 with attribute Released
# Processing sample 69 with attribute Song_Name
# Processing sample 69 with attribute Artist_Name
# Processing sample 69 with attribute Album_Name
# Processing sample 69 with attribute Genre
# Processing sample 69 with attribute Price
# Processing sample 69 with attribute CopyRight
# Processing sample 69 with attribute Time
# Processing sample 69 with attribute Released
# Processing sample 70 with attribute Song_Name
# Processing sample 70 with attribute Artist_Name
# Processing sample 70 with attribute Album_Name
# Processing sample 70 with attribute Genre
# Processing sample 70 with attribute Price
# Processing sample 70 with attribute CopyRight
# Processing sample 70 with attribute Time
# Processing sample 70 with attribute Released
# Processing sample 71 with attribute Song_Name
# Processing sample 71 with attribute Artist_Name
# Processing sample 71 with attribute Album_Name
# Processing sample 71 with attribute Genre
# Processing sample 71 with attribute Price
# Processing sample 71 with attribute CopyRight
# Processing sample 71 with attribute Time
# Processing sample 71 with attribute Released
# Processing sample 72 with attribute Song_Name
# Processing sample 72 with attribute Artist_Name
# Processing sample 72 with attribute Album_Name
# Processing sample 72 with attribute Genre
# Processing sample 72 with attribute Price
# Processing sample 72 with attribute CopyRight
# Processing sample 72 with attribute Time
# Processing sample 72 with attribute Released
# Processing sample 73 with attribute Song_Name
# Processing sample 73 with attribute Artist_Name
# Processing sample 73 with attribute Album_Name
# Processing sample 73 with attribute Genre
# Processing sample 73 with attribute Price
# Processing sample 73 with attribute CopyRight
# Processing sample 73 with attribute Time
# Processing sample 73 with attribute Released
# Processing sample 74 with attribute Song_Name
# Processing sample 74 with attribute Artist_Name
# Processing sample 74 with attribute Album_Name
# Processing sample 74 with attribute Genre
# Processing sample 74 with attribute Price
# Processing sample 74 with attribute CopyRight
# Processing sample 74 with attribute Time
# Processing sample 74 with attribute Released
# Processing sample 75 with attribute Song_Name
# Processing sample 75 with attribute Artist_Name
# Processing sample 75 with attribute Album_Name
# Processing sample 75 with attribute Genre
# Processing sample 75 with attribute Price
# Processing sample 75 with attribute CopyRight
# Processing sample 75 with attribute Time
# Processing sample 75 with attribute Released
# Processing sample 76 with attribute Song_Name
# Processing sample 76 with attribute Artist_Name
# Processing sample 76 with attribute Album_Name
# Processing sample 76 with attribute Genre
# Processing sample 76 with attribute Price
# Processing sample 76 with attribute CopyRight
# Processing sample 76 with attribute Time
# Processing sample 76 with attribute Released
# Processing sample 77 with attribute Song_Name
# Processing sample 77 with attribute Artist_Name
# Processing sample 77 with attribute Album_Name
# Processing sample 77 with attribute Genre
# Processing sample 77 with attribute Price
# Processing sample 77 with attribute CopyRight
# Processing sample 77 with attribute Time
# Processing sample 77 with attribute Released
# Processing sample 78 with attribute Song_Name
# Processing sample 78 with attribute Artist_Name
# Processing sample 78 with attribute Album_Name
# Processing sample 78 with attribute Genre
# Processing sample 78 with attribute Price
# Processing sample 78 with attribute CopyRight
# Processing sample 78 with attribute Time
# Processing sample 78 with attribute Released
# Processing sample 79 with attribute Song_Name
# Processing sample 79 with attribute Artist_Name
# Processing sample 79 with attribute Album_Name
# Processing sample 79 with attribute Genre
# Processing sample 79 with attribute Price
# Processing sample 79 with attribute CopyRight
# Processing sample 79 with attribute Time
# Processing sample 79 with attribute Released
# Processing sample 80 with attribute Song_Name
# Processing sample 80 with attribute Artist_Name
# Processing sample 80 with attribute Album_Name
# Processing sample 80 with attribute Genre
# Processing sample 80 with attribute Price
# Processing sample 80 with attribute CopyRight
# Processing sample 80 with attribute Time
# Processing sample 80 with attribute Released
# Processing sample 81 with attribute Song_Name
# Processing sample 81 with attribute Artist_Name
# Processing sample 81 with attribute Album_Name
# Processing sample 81 with attribute Genre
# Processing sample 81 with attribute Price
# Processing sample 81 with attribute CopyRight
# Processing sample 81 with attribute Time
# Processing sample 81 with attribute Released
# Processing sample 82 with attribute Song_Name
# Processing sample 82 with attribute Artist_Name
# Processing sample 82 with attribute Album_Name
# Processing sample 82 with attribute Genre
# Processing sample 82 with attribute Price
# Processing sample 82 with attribute CopyRight
# Processing sample 82 with attribute Time
# Processing sample 82 with attribute Released
# Processing sample 83 with attribute Song_Name
# Processing sample 83 with attribute Artist_Name
# Processing sample 83 with attribute Album_Name
# Processing sample 83 with attribute Genre
# Processing sample 83 with attribute Price
# Processing sample 83 with attribute CopyRight
# Processing sample 83 with attribute Time
# Processing sample 83 with attribute Released
# Processing sample 84 with attribute Song_Name
# Processing sample 84 with attribute Artist_Name
# Processing sample 84 with attribute Album_Name
# Processing sample 84 with attribute Genre
# Processing sample 84 with attribute Price
# Processing sample 84 with attribute CopyRight
# Processing sample 84 with attribute Time
# Processing sample 84 with attribute Released
# Processing sample 85 with attribute Song_Name
# Processing sample 85 with attribute Artist_Name
# Processing sample 85 with attribute Album_Name
# Processing sample 85 with attribute Genre
# Processing sample 85 with attribute Price
# Processing sample 85 with attribute CopyRight
# Processing sample 85 with attribute Time
# Processing sample 85 with attribute Released
# Processing sample 86 with attribute Song_Name
# Processing sample 86 with attribute Artist_Name
# Processing sample 86 with attribute Album_Name
# Processing sample 86 with attribute Genre
# Processing sample 86 with attribute Price
# Processing sample 86 with attribute CopyRight
# Processing sample 86 with attribute Time
# Processing sample 86 with attribute Released
# Processing sample 87 with attribute Song_Name
# Processing sample 87 with attribute Artist_Name
# Processing sample 87 with attribute Album_Name
# Processing sample 87 with attribute Genre
# Processing sample 87 with attribute Price
# Processing sample 87 with attribute CopyRight
# Processing sample 87 with attribute Time
# Processing sample 87 with attribute Released
# Processing sample 88 with attribute Song_Name
# Processing sample 88 with attribute Artist_Name
# Processing sample 88 with attribute Album_Name
# Processing sample 88 with attribute Genre
# Processing sample 88 with attribute Price
# Processing sample 88 with attribute CopyRight
# Processing sample 88 with attribute Time
# Processing sample 88 with attribute Released
# Processing sample 89 with attribute Song_Name
# Processing sample 89 with attribute Artist_Name
# Processing sample 89 with attribute Album_Name
# Processing sample 89 with attribute Genre
# Processing sample 89 with attribute Price
# Processing sample 89 with attribute CopyRight
# Processing sample 89 with attribute Time
# Processing sample 89 with attribute Released
# Processing sample 90 with attribute Song_Name
# Processing sample 90 with attribute Artist_Name
# Processing sample 90 with attribute Album_Name
# Processing sample 90 with attribute Genre
# Processing sample 90 with attribute Price
# Processing sample 90 with attribute CopyRight
# Processing sample 90 with attribute Time
# Processing sample 90 with attribute Released
# Processing sample 91 with attribute Song_Name
# Processing sample 91 with attribute Artist_Name
# Processing sample 91 with attribute Album_Name
# Processing sample 91 with attribute Genre
# Processing sample 91 with attribute Price
# Processing sample 91 with attribute CopyRight
# Processing sample 91 with attribute Time
# Processing sample 91 with attribute Released
# Processing sample 92 with attribute Song_Name
# Processing sample 92 with attribute Artist_Name
# Processing sample 92 with attribute Album_Name
# Processing sample 92 with attribute Genre
# Processing sample 92 with attribute Price
# Processing sample 92 with attribute CopyRight
# Processing sample 92 with attribute Time
# Processing sample 92 with attribute Released
# Processing sample 93 with attribute Song_Name
# Processing sample 93 with attribute Artist_Name
# Processing sample 93 with attribute Album_Name
# Processing sample 93 with attribute Genre
# Processing sample 93 with attribute Price
# Processing sample 93 with attribute CopyRight
# Processing sample 93 with attribute Time
# Processing sample 93 with attribute Released
# Processing sample 94 with attribute Song_Name
# Processing sample 94 with attribute Artist_Name
# Processing sample 94 with attribute Album_Name
# Processing sample 94 with attribute Genre
# Processing sample 94 with attribute Price
# Processing sample 94 with attribute CopyRight
# Processing sample 94 with attribute Time
# Processing sample 94 with attribute Released
# Processing sample 95 with attribute Song_Name
# Processing sample 95 with attribute Artist_Name
# Processing sample 95 with attribute Album_Name
# Processing sample 95 with attribute Genre
# Processing sample 95 with attribute Price
# Processing sample 95 with attribute CopyRight
# Processing sample 95 with attribute Time
# Processing sample 95 with attribute Released
# Processing sample 96 with attribute Song_Name
# Processing sample 96 with attribute Artist_Name
# Processing sample 96 with attribute Album_Name
# Processing sample 96 with attribute Genre
# Processing sample 96 with attribute Price
# Processing sample 96 with attribute CopyRight
# Processing sample 96 with attribute Time
# Processing sample 96 with attribute Released
# Processing sample 97 with attribute Song_Name
# Processing sample 97 with attribute Artist_Name
# Processing sample 97 with attribute Album_Name
# Processing sample 97 with attribute Genre
# Processing sample 97 with attribute Price
# Processing sample 97 with attribute CopyRight
# Processing sample 97 with attribute Time
# Processing sample 97 with attribute Released
# Processing sample 98 with attribute Song_Name
# Processing sample 98 with attribute Artist_Name
# Processing sample 98 with attribute Album_Name
# Processing sample 98 with attribute Genre
# Processing sample 98 with attribute Price
# Processing sample 98 with attribute CopyRight
# Processing sample 98 with attribute Time
# Processing sample 98 with attribute Released
# Processing sample 99 with attribute Song_Name
# Processing sample 99 with attribute Artist_Name
# Processing sample 99 with attribute Album_Name
# Processing sample 99 with attribute Genre
# Processing sample 99 with attribute Price
# Processing sample 99 with attribute CopyRight
# Processing sample 99 with attribute Time
# Processing sample 99 with attribute Released
# Processing sample 100 with attribute Song_Name
# Processing sample 100 with attribute Artist_Name
# Processing sample 100 with attribute Album_Name
# Processing sample 100 with attribute Genre
# Processing sample 100 with attribute Price
# Processing sample 100 with attribute CopyRight
# Processing sample 100 with attribute Time
# Processing sample 100 with attribute Released
# Processing sample 101 with attribute Song_Name
# Processing sample 101 with attribute Artist_Name
# Processing sample 101 with attribute Album_Name
# Processing sample 101 with attribute Genre
# Processing sample 101 with attribute Price
# Processing sample 101 with attribute CopyRight
# Processing sample 101 with attribute Time
# Processing sample 101 with attribute Released
# Processing sample 102 with attribute Song_Name
# Processing sample 102 with attribute Artist_Name
# Processing sample 102 with attribute Album_Name
# Processing sample 102 with attribute Genre
# Processing sample 102 with attribute Price
# Processing sample 102 with attribute CopyRight
# Processing sample 102 with attribute Time
# Processing sample 102 with attribute Released
# Processing sample 103 with attribute Song_Name
# Processing sample 103 with attribute Artist_Name
# Processing sample 103 with attribute Album_Name
# Processing sample 103 with attribute Genre
# Processing sample 103 with attribute Price
# Processing sample 103 with attribute CopyRight
# Processing sample 103 with attribute Time
# Processing sample 103 with attribute Released
# Processing sample 104 with attribute Song_Name
# Processing sample 104 with attribute Artist_Name
# Processing sample 104 with attribute Album_Name
# Processing sample 104 with attribute Genre
# Processing sample 104 with attribute Price
# Processing sample 104 with attribute CopyRight
# Processing sample 104 with attribute Time
# Processing sample 104 with attribute Released
# Processing sample 105 with attribute Song_Name
# Processing sample 105 with attribute Artist_Name
# Processing sample 105 with attribute Album_Name
# Processing sample 105 with attribute Genre
# Processing sample 105 with attribute Price
# Processing sample 105 with attribute CopyRight
# Processing sample 105 with attribute Time
# Processing sample 105 with attribute Released
# Processing sample 106 with attribute Song_Name
# Processing sample 106 with attribute Artist_Name
# Processing sample 106 with attribute Album_Name
# Processing sample 106 with attribute Genre
# Processing sample 106 with attribute Price
# Processing sample 106 with attribute CopyRight
# Processing sample 106 with attribute Time
# Processing sample 106 with attribute Released
# Processing sample 107 with attribute Song_Name
# Processing sample 107 with attribute Artist_Name
# Processing sample 107 with attribute Album_Name
# Processing sample 107 with attribute Genre
# Processing sample 107 with attribute Price
# Processing sample 107 with attribute CopyRight
# Processing sample 107 with attribute Time
# Processing sample 107 with attribute Released
# Processing sample 108 with attribute Song_Name
# Processing sample 108 with attribute Artist_Name
# Processing sample 108 with attribute Album_Name
# Processing sample 108 with attribute Genre
# Processing sample 108 with attribute Price
# Processing sample 108 with attribute CopyRight
# Processing sample 108 with attribute Time
# Processing sample 108 with attribute Released
# Processing sample 109 with attribute Song_Name
# Processing sample 109 with attribute Artist_Name
# Processing sample 109 with attribute Album_Name
# Processing sample 109 with attribute Genre
# Processing sample 109 with attribute Price
# Processing sample 109 with attribute CopyRight
# Processing sample 109 with attribute Time
# Processing sample 109 with attribute Released
# Processing sample 110 with attribute Song_Name
# Processing sample 110 with attribute Artist_Name
# Processing sample 110 with attribute Album_Name
# Processing sample 110 with attribute Genre
# Processing sample 110 with attribute Price
# Processing sample 110 with attribute CopyRight
# Processing sample 110 with attribute Time
# Processing sample 110 with attribute Released
# Processing sample 111 with attribute Song_Name
# Processing sample 111 with attribute Artist_Name
# Processing sample 111 with attribute Album_Name
# Processing sample 111 with attribute Genre
# Processing sample 111 with attribute Price
# Processing sample 111 with attribute CopyRight
# Processing sample 111 with attribute Time
# Processing sample 111 with attribute Released
# Processing sample 112 with attribute Song_Name
# Processing sample 112 with attribute Artist_Name
# Processing sample 112 with attribute Album_Name
# Processing sample 112 with attribute Genre
# Processing sample 112 with attribute Price
# Processing sample 112 with attribute CopyRight
# Processing sample 112 with attribute Time
# Processing sample 112 with attribute Released
# Processing sample 113 with attribute Song_Name
# Processing sample 113 with attribute Artist_Name
# Processing sample 113 with attribute Album_Name
# Processing sample 113 with attribute Genre
# Processing sample 113 with attribute Price
# Processing sample 113 with attribute CopyRight
# Processing sample 113 with attribute Time
# Processing sample 113 with attribute Released
# Processing sample 114 with attribute Song_Name
# Processing sample 114 with attribute Artist_Name
# Processing sample 114 with attribute Album_Name
# Processing sample 114 with attribute Genre
# Processing sample 114 with attribute Price
# Processing sample 114 with attribute CopyRight
# Processing sample 114 with attribute Time
# Processing sample 114 with attribute Released
# Processing sample 115 with attribute Song_Name
# Processing sample 115 with attribute Artist_Name
# Processing sample 115 with attribute Album_Name
# Processing sample 115 with attribute Genre
# Processing sample 115 with attribute Price
# Processing sample 115 with attribute CopyRight
# Processing sample 115 with attribute Time
# Processing sample 115 with attribute Released
# Processing sample 116 with attribute Song_Name
# Processing sample 116 with attribute Artist_Name
# Processing sample 116 with attribute Album_Name
# Processing sample 116 with attribute Genre
# Processing sample 116 with attribute Price
# Processing sample 116 with attribute CopyRight
# Processing sample 116 with attribute Time
# Processing sample 116 with attribute Released
# Processing sample 117 with attribute Song_Name
# Processing sample 117 with attribute Artist_Name
# Processing sample 117 with attribute Album_Name
# Processing sample 117 with attribute Genre
# Processing sample 117 with attribute Price
# Processing sample 117 with attribute CopyRight
# Processing sample 117 with attribute Time
# Processing sample 117 with attribute Released
# Processing sample 118 with attribute Song_Name
# Processing sample 118 with attribute Artist_Name
# Processing sample 118 with attribute Album_Name
# Processing sample 118 with attribute Genre
# Processing sample 118 with attribute Price
# Processing sample 118 with attribute CopyRight
# Processing sample 118 with attribute Time
# Processing sample 118 with attribute Released
# Processing sample 119 with attribute Song_Name
# Processing sample 119 with attribute Artist_Name
# Processing sample 119 with attribute Album_Name
# Processing sample 119 with attribute Genre
# Processing sample 119 with attribute Price
# Processing sample 119 with attribute CopyRight
# Processing sample 119 with attribute Time
# Processing sample 119 with attribute Released
# Processing sample 120 with attribute Song_Name
# Processing sample 120 with attribute Artist_Name
# Processing sample 120 with attribute Album_Name
# Processing sample 120 with attribute Genre
# Processing sample 120 with attribute Price
# Processing sample 120 with attribute CopyRight
# Processing sample 120 with attribute Time
# Processing sample 120 with attribute Released
# Processing sample 121 with attribute Song_Name
# Processing sample 121 with attribute Artist_Name
# Processing sample 121 with attribute Album_Name
# Processing sample 121 with attribute Genre
# Processing sample 121 with attribute Price
# Processing sample 121 with attribute CopyRight
# Processing sample 121 with attribute Time
# Processing sample 121 with attribute Released
# Processing sample 122 with attribute Song_Name
# Processing sample 122 with attribute Artist_Name
# Processing sample 122 with attribute Album_Name
# Processing sample 122 with attribute Genre
# Processing sample 122 with attribute Price
# Processing sample 122 with attribute CopyRight
# Processing sample 122 with attribute Time
# Processing sample 122 with attribute Released
# Processing sample 123 with attribute Song_Name
# Processing sample 123 with attribute Artist_Name
# Processing sample 123 with attribute Album_Name
# Processing sample 123 with attribute Genre
# Processing sample 123 with attribute Price
# Processing sample 123 with attribute CopyRight
# Processing sample 123 with attribute Time
# Processing sample 123 with attribute Released
# Processing sample 124 with attribute Song_Name
# Processing sample 124 with attribute Artist_Name
# Processing sample 124 with attribute Album_Name
# Processing sample 124 with attribute Genre
# Processing sample 124 with attribute Price
# Processing sample 124 with attribute CopyRight
# Processing sample 124 with attribute Time
# Processing sample 124 with attribute Released
# Processing sample 125 with attribute Song_Name
# Processing sample 125 with attribute Artist_Name
# Processing sample 125 with attribute Album_Name
# Processing sample 125 with attribute Genre
# Processing sample 125 with attribute Price
# Processing sample 125 with attribute CopyRight
# Processing sample 125 with attribute Time
# Processing sample 125 with attribute Released
# Processing sample 126 with attribute Song_Name
# Processing sample 126 with attribute Artist_Name
# Processing sample 126 with attribute Album_Name
# Processing sample 126 with attribute Genre
# Processing sample 126 with attribute Price
# Processing sample 126 with attribute CopyRight
# Processing sample 126 with attribute Time
# Processing sample 126 with attribute Released
# Processing sample 127 with attribute Song_Name
# Processing sample 127 with attribute Artist_Name
# Processing sample 127 with attribute Album_Name
# Processing sample 127 with attribute Genre
# Processing sample 127 with attribute Price
# Processing sample 127 with attribute CopyRight
# Processing sample 127 with attribute Time
# Processing sample 127 with attribute Released
# Processing sample 128 with attribute Song_Name
# Processing sample 128 with attribute Artist_Name
# Processing sample 128 with attribute Album_Name
# Processing sample 128 with attribute Genre
# Processing sample 128 with attribute Price
# Processing sample 128 with attribute CopyRight
# Processing sample 128 with attribute Time
# Processing sample 128 with attribute Released
# Processing sample 129 with attribute Song_Name
# Processing sample 129 with attribute Artist_Name
# Processing sample 129 with attribute Album_Name
# Processing sample 129 with attribute Genre
# Processing sample 129 with attribute Price
# Processing sample 129 with attribute CopyRight
# Processing sample 129 with attribute Time
# Processing sample 129 with attribute Released
# Processing sample 130 with attribute Song_Name
# Processing sample 130 with attribute Artist_Name
# Processing sample 130 with attribute Album_Name
# Processing sample 130 with attribute Genre
# Processing sample 130 with attribute Price
# Processing sample 130 with attribute CopyRight
# Processing sample 130 with attribute Time
# Processing sample 130 with attribute Released
# Processing sample 131 with attribute Song_Name
# Processing sample 131 with attribute Artist_Name
# Processing sample 131 with attribute Album_Name
# Processing sample 131 with attribute Genre
# Processing sample 131 with attribute Price
# Processing sample 131 with attribute CopyRight
# Processing sample 131 with attribute Time
# Processing sample 131 with attribute Released

# %%
ri_norms = []
for ri_list in positive_samples_ri_matrix:
    ri_norms.append(list(map(lambda x:torch.norm(x).data[0],ri_list)))

# %%
import pandas as pd
variation_df = pd.DataFrame(data= ri_norms,columns=attributes)

# %%
columns = list(variation_df)
sum_ri = {}
for col in columns:
    sum_ri[col] = variation_df[col].sum()

# %%
variation_df.head()
# Out:
#    Song_Name  Artist_Name  Album_Name      Genre     Price  CopyRight  \
# 0   7.416443    13.066339    8.910498  12.662943  6.983381  13.214828
# 1   2.136887     4.404752    2.567972   4.219779  2.152426   4.470359
# 2   6.656691    13.037644    8.273711  12.339103  6.536732  13.250337
# 3   3.488452     8.492527    4.448065   7.887391  3.816852   8.639491
# 4   6.879353    12.734942    8.432244  12.403474  6.483789  12.839190
#
#        Time   Released
# 0  6.004185  12.095785
# 1  1.736317   4.142581
# 2  5.355540  11.901794
# 3  3.586415   8.347251
# 4  5.808014  11.691287

# %%
sum_ri
# Out:
# {'Song_Name': 814.1031942367554,
#  'Artist_Name': 1280.9989819526672,
#  'Album_Name': 967.4343025684357,
#  'Genre': 1249.8788282871246,
#  'Price': 718.3666291236877,
#  'CopyRight': 1289.2608795166016,
#  'Time': 695.3380416631699,
#  'Released': 1186.7523791790009}

# %%
variation_df.to_csv('experiments-results/positive_samples_ri_truegradient.csv',index=False,sep=';')

# %% [markdown]
# ## Finding closer vectors

# %%
from scipy.spatial.distance import euclidean
def get_closer_vector(v,batch_list):
    min_distance = 10000000
    i = 0
    best_sample = i
    for batch in batch_list:
        for sample in batch:
            curr_distance = euclidean(v.data,sample.data)
            if curr_distance< min_distance:
                min_distance = curr_distance
                best_sample = i
            i+=1
    return best_sample

# %%
def get_closer_vector_on_attribute(v,batch_list,attribute_idx,attribute_lenght):
    min_distance = 1000000
    i = 0
    best_sample = i
    start_index = attribute_idx*attribute_lenght
    end_index = start_index+attribute_lenght
    v_attribute_selected = v[start_index:end_index]
    for batch in batch_list:
        for sample in batch:
            curr_distance = euclidean(v_attribute_selected.data,sample[start_index:end_index].data)
            if curr_distance < min_distance:
                min_distance = curr_distance
                best_sample = i
            i+=1
    return best_sample

# %%
#test
closer_sample_index = get_closer_vector_on_attribute(positive_classifier_inputs[0][10],positive_classifier_inputs,0,150)

# %%
closer_sample_index

# %%
idx = get_closer_vector_on_attribute(positive_classifier_inputs[4][5],negative_classifier_inputs,0,150)

# %%
idx

# %%
positive_batches[4].id

# %%
#lista di tuple: vettore più vicino considerando tutti gli elementi e closer solo secondo un attributo
closer_vectors = []
i = 0
for batch in negative_classifier_inputs:
    for sample in batch:
        # lista di coppie in cui il primo elemento indica il campione più vicino considerando tutti gli elementi
        # e il secondo indica il più vicino considerando il singolo attributo
        current_sample_closer_vectors = []
        for j,attribute in enumerate(attributes):
            curr_ri = negatives_ri_matrix[i][j]
            altered_sample = sample + curr_ri
            closer_index = get_closer_vector(altered_sample,positive_classifier_inputs)
            closer_on_attribute = get_closer_vector_on_attribute(altered_sample,
                                                                               positive_classifier_inputs,j,150)
            current_sample_closer_vectors.append((closer_index,closer_on_attribute))
        closer_vectors.append(current_sample_closer_vectors)
        i += 1

# %%
#lista di tuple: vettore piu' vicino, batch index e sample index
positives_closer_vectors = []
i = 0
for batch in positive_classifier_inputs:
    for sample in batch:
        current_sample_closer_vectors = []
        for j,attribute in enumerate(attributes):
            curr_ri = positive_samples_ri_matrix[i][j]
            altered_sample = sample + curr_ri
            closer_index = get_closer_vector(altered_sample,negative_classifier_inputs)
            closer_on_attribute_index = get_closer_vector_on_attribute(altered_sample,
                                                                               negative_classifier_inputs,j,150)
            current_sample_closer_vectors.append((closer_index,closer_on_attribute_index))
        positives_closer_vectors.append(current_sample_closer_vectors)
        i += 1

# %%
ordered_id_positives = []
for batch in positive_batches:
    ordered_id_positives = ordered_id_positives+batch.id

# %%
ordered_id_negatives = []
for batch in negative_batches:
    ordered_id_negatives = ordered_id_negatives+batch.id

# %%
closer_vectors[1]

# %%
positives_closer_vectors_df = pd.DataFrame(data= positives_closer_vectors,columns =attributes)

# %%
positives_closer_vectors_df.head()

# %%
negatives_closer_vectors_df = pd.DataFrame(data = closer_vectors, columns = attributes)

# %%
negatives_closer_vectors_df.head()

# %%
positives_closer_vectors_df = positives_closer_vectors_df.applymap(lambda c: (ordered_id_negatives[c[0]],
                                                                   ordered_id_negatives[c[1]]))

# %%
positives_closer_vectors_df.head()

# %%
negatives_closer_vectors_df = negatives_closer_vectors_df.applymap(lambda c: (ordered_id_positives[c[0]],
                                                                   ordered_id_positives[c[1]]))

# %%
negatives_closer_vectors_df.head()

# %%
positives_closer_vectors_on_attribute_df = positives_closer_vectors_df.applymap(lambda c: c[1])

# %%
positives_closer_vectors_on_attribute_df.head()

# %%
negatives_closer_vectors_on_attribute_df = negatives_closer_vectors_df.applymap(lambda c : c[1])

# %%
positives_closer_vectors_df['Pos_sample_ID']= ordered_id_positives
positives_closer_vectors_on_attribute_df['Pos_sample_ID'] = ordered_id_positives

# %%
positives_closer_vectors_df.to_csv('positives_closer_vectors.csv',sep=';',index=False)

# %%
positives_closer_vectors_on_attribute_df.to_csv('positives_closer_vectors_on_attribute.csv',sep=';',index=False)

# %%
negatives_closer_vectors_df['Neg_sample_ID'] = ordered_id_negatives
negatives_closer_vectors_on_attribute_df['Neg_sample_ID'] = ordered_id_negatives

# %%
negatives_closer_vectors_df.to_csv('negatives_closer_vectors.csv',sep=';',index=False)
negatives_closer_vectors_on_attribute_df.to_csv('negatives_closer_vector_on_attribute.csv',sep=';',index=False)

# %% [markdown]
# ### Some tests

# %%
it,variation = find_smallest_variation_to_change(hybrid_model.classifier,positive_classifier_inputs[0],20,6,0)

# %%
positive_classifier_inputs[0][20].data = positive_classifier_inputs[0][20].data.copy_(positive_classifier_inputs[0][20].data+
                                                                                     variation.data)

# %%
hybrid_model.classifier.forward(positive_classifier_inputs[0])[20]

# %%
grads_list = []
h = positive_classifier_inputs[0].register_hook(lambda g: grads_list.append(g))

# %%
out = hybrid_model.classifier.forward(positive_classifier_inputs[0])
prob = get_probabilites(out[20])

# %%
from torch.autograd import Variable
true_labels = Variable (torch.cuda.FloatTensor([0,1]))
