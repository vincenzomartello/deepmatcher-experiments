# %%
import sys
sys.path.append("../..")

# %%
import deepmatcher as dm
from utilities_functions.dataset_parser import generate_train_valid_test

# %%
train,valid,test = generate_train_valid_test('../../Structured/Beer/','ltable_','rtable_')

# %%
train[train['label']==0].shape
# Out:
# (228, 10)

# %%
train[train['label']==1].shape
# Out:
# (40, 10)

# %%
train.to_csv('../../Structured/Beer/merged_train.csv',index=False)
valid.to_csv('../../Structured/Beer/merged_valid.csv',index=False)
test.to_csv('../../Structured/Beer/merged_test.csv',index=False)

# %%
test_pos = test[test['label']==0]
test_neg = test[test['label']==1]

# %%
test_pos.to_csv('../../Structured/Beer/test_negatives.csv',index=False)
test_neg.to_csv('../../Structured/Beer/test_positives.csv',index=False)

# %%
train.to_csv('../../Structured/Beer/train_imperialredale_positives.csv',index=False)

# %%
train,valid,test = dm.data.process('../../Structured/Beer',train='merged_train.csv',validation='merged_valid.csv',
                                  test='merged_test.csv',left_prefix='ltable_',right_prefix='rtable_')
# Out:
# WARNING:deepmatcher.data.dataset:Rebuilding data cache because: ['One or more data files have been modified.']

# %%
hybrid_model = dm.MatchingModel(attr_summarizer='hybrid')

# %%
hybrid_model.run_train(train,valid,best_save_path='../../models/beer_balanced_hybrid.pth',epochs=20,pos_neg_ratio=4,batch_size=16)
# Out:
# * Number of trainable parameters: 9210006
# ===>  TRAIN Epoch 1
# Finished Epoch 1 || Run Time:    3.6 | Load Time:    0.4 || F1:  30.97 | Prec:  20.87 | Rec:  60.00 || Ex/s:  66.02
#
# ===>  EVAL Epoch 1
# Finished Epoch 1 || Run Time:    0.4 | Load Time:    0.1 || F1:  27.18 | Prec:  15.73 | Rec: 100.00 || Ex/s: 177.89
#
# * Best F1: 27.184466019417474
# Saving best model...
# Done.
# ---------------------
#
# ===>  TRAIN Epoch 2
# Finished Epoch 2 || Run Time:    3.5 | Load Time:    0.5 || F1:  43.48 | Prec:  30.61 | Rec:  75.00 || Ex/s:  67.37
#
# ===>  EVAL Epoch 2
# Finished Epoch 2 || Run Time:    0.4 | Load Time:    0.1 || F1:  40.58 | Prec:  25.45 | Rec: 100.00 || Ex/s: 178.72
#
# * Best F1: 40.57971014492754
# Saving best model...
# Done.
# ---------------------
#
# ===>  TRAIN Epoch 3
# Finished Epoch 3 || Run Time:    3.4 | Load Time:    0.5 || F1:  63.25 | Prec:  48.05 | Rec:  92.50 || Ex/s:  69.36
#
# ===>  EVAL Epoch 3
# Finished Epoch 3 || Run Time:    0.4 | Load Time:    0.1 || F1:  45.90 | Prec:  29.79 | Rec: 100.00 || Ex/s: 178.66
#
# * Best F1: 45.90163934426229
# Saving best model...
# Done.
# ---------------------
#
# ===>  TRAIN Epoch 4
# Finished Epoch 4 || Run Time:    3.4 | Load Time:    0.5 || F1:  80.85 | Prec:  70.37 | Rec:  95.00 || Ex/s:  70.00
#
# ===>  EVAL Epoch 4
# Finished Epoch 4 || Run Time:    0.4 | Load Time:    0.1 || F1:  54.90 | Prec:  37.84 | Rec: 100.00 || Ex/s: 176.87
#
# * Best F1: 54.90196078431372
# Saving best model...
# Done.
# ---------------------
#
# ===>  TRAIN Epoch 5
# Finished Epoch 5 || Run Time:    3.4 | Load Time:    0.5 || F1:  86.36 | Prec:  79.17 | Rec:  95.00 || Ex/s:  68.66
#
# ===>  EVAL Epoch 5
# Finished Epoch 5 || Run Time:    0.4 | Load Time:    0.1 || F1:  80.00 | Prec:  75.00 | Rec:  85.71 || Ex/s: 179.32
#
# * Best F1: 80.0
# Saving best model...
# Done.
# ---------------------
#
# ===>  TRAIN Epoch 6
# Finished Epoch 6 || Run Time:    3.5 | Load Time:    0.5 || F1:  91.95 | Prec:  85.11 | Rec: 100.00 || Ex/s:  68.50
#
# ===>  EVAL Epoch 6
# Finished Epoch 6 || Run Time:    0.4 | Load Time:    0.1 || F1:  80.00 | Prec:  75.00 | Rec:  85.71 || Ex/s: 178.64
#
# ---------------------
#
# ===>  TRAIN Epoch 7
# Finished Epoch 7 || Run Time:    3.4 | Load Time:    0.4 || F1:  98.77 | Prec:  97.56 | Rec: 100.00 || Ex/s:  69.48
#
# ===>  EVAL Epoch 7
# Finished Epoch 7 || Run Time:    0.4 | Load Time:    0.1 || F1:  68.57 | Prec:  57.14 | Rec:  85.71 || Ex/s: 176.72
#
# ---------------------
#
# ===>  TRAIN Epoch 8
# Finished Epoch 8 || Run Time:    3.4 | Load Time:    0.4 || F1:  98.77 | Prec:  97.56 | Rec: 100.00 || Ex/s:  69.99
#
# ===>  EVAL Epoch 8
# Finished Epoch 8 || Run Time:    0.4 | Load Time:    0.1 || F1:  75.00 | Prec:  66.67 | Rec:  85.71 || Ex/s: 176.45
#
# ---------------------
#
# ===>  TRAIN Epoch 9
# Finished Epoch 9 || Run Time:    3.6 | Load Time:    0.5 || F1:  98.77 | Prec:  97.56 | Rec: 100.00 || Ex/s:  66.52
#
# ===>  EVAL Epoch 9
# Finished Epoch 9 || Run Time:    0.4 | Load Time:    0.1 || F1:  75.00 | Prec:  66.67 | Rec:  85.71 || Ex/s: 179.35
#
# ---------------------
#
# ===>  TRAIN Epoch 10
# Finished Epoch 10 || Run Time:    3.5 | Load Time:    0.4 || F1:  98.77 | Prec:  97.56 | Rec: 100.00 || Ex/s:  68.16
#
# ===>  EVAL Epoch 10
# Finished Epoch 10 || Run Time:    0.4 | Load Time:    0.1 || F1:  75.00 | Prec:  66.67 | Rec:  85.71 || Ex/s: 178.45
#
# ---------------------
#
# ===>  TRAIN Epoch 11
# Finished Epoch 11 || Run Time:    3.4 | Load Time:    0.5 || F1:  98.77 | Prec:  97.56 | Rec: 100.00 || Ex/s:  69.73
#
# ===>  EVAL Epoch 11
# Finished Epoch 11 || Run Time:    0.4 | Load Time:    0.1 || F1:  75.00 | Prec:  66.67 | Rec:  85.71 || Ex/s: 178.58
#
# ---------------------
#
# ===>  TRAIN Epoch 12
# Finished Epoch 12 || Run Time:    3.4 | Load Time:    0.5 || F1:  98.77 | Prec:  97.56 | Rec: 100.00 || Ex/s:  69.90
#
# ===>  EVAL Epoch 12
# Finished Epoch 12 || Run Time:    0.4 | Load Time:    0.1 || F1:  75.00 | Prec:  66.67 | Rec:  85.71 || Ex/s: 177.65
#
# ---------------------
#
# ===>  TRAIN Epoch 13
# Finished Epoch 13 || Run Time:    3.5 | Load Time:    0.5 || F1:  98.77 | Prec:  97.56 | Rec: 100.00 || Ex/s:  67.80
#
# ===>  EVAL Epoch 13
# Finished Epoch 13 || Run Time:    0.4 | Load Time:    0.1 || F1:  75.00 | Prec:  66.67 | Rec:  85.71 || Ex/s: 177.64
#
# ---------------------
#
# ===>  TRAIN Epoch 14
# Finished Epoch 14 || Run Time:    3.5 | Load Time:    0.5 || F1:  98.77 | Prec:  97.56 | Rec: 100.00 || Ex/s:  67.60
#
# ===>  EVAL Epoch 14
# Finished Epoch 14 || Run Time:    0.4 | Load Time:    0.1 || F1:  75.00 | Prec:  66.67 | Rec:  85.71 || Ex/s: 179.10
#
# ---------------------
#
# ===>  TRAIN Epoch 15
# Finished Epoch 15 || Run Time:    3.5 | Load Time:    0.5 || F1:  98.77 | Prec:  97.56 | Rec: 100.00 || Ex/s:  67.42
#
# ===>  EVAL Epoch 15
# Finished Epoch 15 || Run Time:    0.4 | Load Time:    0.1 || F1:  75.00 | Prec:  66.67 | Rec:  85.71 || Ex/s: 178.63
#
# ---------------------
#
# ===>  TRAIN Epoch 16
# Finished Epoch 16 || Run Time:    3.5 | Load Time:    0.5 || F1:  98.77 | Prec:  97.56 | Rec: 100.00 || Ex/s:  67.73
#
# ===>  EVAL Epoch 16
# Finished Epoch 16 || Run Time:    0.4 | Load Time:    0.1 || F1:  75.00 | Prec:  66.67 | Rec:  85.71 || Ex/s: 177.83
#
# ---------------------
#
# ===>  TRAIN Epoch 17
# Finished Epoch 17 || Run Time:    3.6 | Load Time:    0.5 || F1: 100.00 | Prec: 100.00 | Rec: 100.00 || Ex/s:  66.11
#
# ===>  EVAL Epoch 17
# Finished Epoch 17 || Run Time:    0.4 | Load Time:    0.1 || F1:  75.00 | Prec:  66.67 | Rec:  85.71 || Ex/s: 178.72
#
# ---------------------
#
# ===>  TRAIN Epoch 18
# Finished Epoch 18 || Run Time:    3.5 | Load Time:    0.4 || F1: 100.00 | Prec: 100.00 | Rec: 100.00 || Ex/s:  67.97
#
# ===>  EVAL Epoch 18
# Finished Epoch 18 || Run Time:    0.4 | Load Time:    0.1 || F1:  75.00 | Prec:  66.67 | Rec:  85.71 || Ex/s: 175.46
#
# ---------------------
#
# ===>  TRAIN Epoch 19
# Finished Epoch 19 || Run Time:    3.5 | Load Time:    0.5 || F1: 100.00 | Prec: 100.00 | Rec: 100.00 || Ex/s:  68.12
#
# ===>  EVAL Epoch 19
# Finished Epoch 19 || Run Time:    0.4 | Load Time:    0.1 || F1:  75.00 | Prec:  66.67 | Rec:  85.71 || Ex/s: 178.34
#
# ---------------------
#
# ===>  TRAIN Epoch 20
# Finished Epoch 20 || Run Time:    3.5 | Load Time:    0.5 || F1: 100.00 | Prec: 100.00 | Rec: 100.00 || Ex/s:  67.14
#
# ===>  EVAL Epoch 20
# Finished Epoch 20 || Run Time:    0.4 | Load Time:    0.1 || F1:  75.00 | Prec:  66.67 | Rec:  85.71 || Ex/s: 178.08
#
# ---------------------
#
# Loading best model...
# Training done.
# 80.0

# %%
hybrid_model.run_eval(test)
# Out:
# ===>  EVAL Epoch 5
# Finished Epoch 5 || Run Time:    0.2 | Load Time:    0.1 || F1:  68.75 | Prec:  61.11 | Rec:  78.57 || Ex/s: 265.89
# 68.75

# %%
test = dm.data.process_unlabeled("../../Structured/Beer/positives.csv",hybrid_model,ignore_columns=["id","label"])

# %%
hybrid_model.run_prediction(test)
# Out:
# ===>  PREDICT Epoch 3
# Finished Epoch 3 || Run Time:    0.2 | Load Time:    0.1 || F1:   0.00 | Prec:   0.00 | Rec:   0.00 || Ex/s:   0.00
#      match_score
# id
# 98      0.953142
# 223     0.987418
# 184     0.959727
# 205     0.882277
# 68      0.998649
# 147     0.970523
# 79      0.987863
# 248     0.939790
# 233     0.946810
# 126     0.957019
# 27      0.999722
# 17      0.981406
# 220     0.976878
# 104     0.998912
# 53      0.958687
# 114     0.895904
# 144     0.966067
# 129     0.999115
# 69      0.996418
# 87      0.998737
# 66      0.984349
# 85      0.889301
# 190     0.983256
# 177     0.976883
# 64      0.824194
# 214     0.997552
# 138     0.989902
# 0       0.999784
# 95      0.950180
# 225     0.997436
# ..           ...
# 218     0.999075
# 200     0.989080
# 406     0.987346
# 428     0.831205
# 382     0.675562
# 408     0.209028
# 381     0.738844
# 410     0.308668
# 424     0.970504
# 393     0.499485
# 412     0.865766
# 425     0.860366
# 383     0.591301
# 433     0.877483
# 414     0.940648
# 418     0.860197
# 572     0.885501
# 607     0.771415
# 575     0.837082
# 612     0.970110
# 615     0.626185
# 571     0.173651
# 599     0.675218
# 568     0.604738
# 577     0.494943
# 579     0.259255
# 608     0.479324
# 573     0.306962
# 583     0.491642
# 609     0.762138
#
# [68 rows x 1 columns]
