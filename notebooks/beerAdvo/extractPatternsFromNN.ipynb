# %%
import sys
sys.path.append('../..')

# %%
import pandas as pd
from utils.patternDiscovery import mineRules

# %%
pos_nn = pd.read_csv('experiment-results/positivesNNhybrid.csv')
negatives = pd.read_csv('../../Structured/Beer/negatives.csv')
ass_rules_onBeerName = mineRules(pos_nn,negatives,'Beer_Name',min_confidence=0.8,min_support=0.1)
ass_rules_onBeerName.shape
# Out:
# (1839, 11)

# %% [markdown]
# ## Analyze NN calculated only from training set

# %%
pos_nn_onlytrain = pd.read_csv('experiment-results/positivesNNhybrid_onlytrain.csv')
train_neg = pd.read_csv('../../Structured/Beer/train_negatives.csv')
ass_rules_onBeerName_ot = mineRules(pos_nn_onlytrain,train_neg,'Beer_Name',min_confidence=0.8,min_support=0.2)
ass_rules_onBeerName_ot.shape
# Out:
# (41, 11)

# %%
ass_rules_onBeerName_ot.head(40)
# Out:
#                     antecedents                 consequents  \
# 1                       (L_Ale)                     (R_Ale)
# 3                       (L_Red)                     (R_Ale)
# 5                (L_Ale, L_Red)                     (R_Ale)
# 8                       (L_Red)                     (R_Red)
# 12               (L_Ale, L_Red)                     (R_Red)
# 23                      (L_Red)              (R_Ale, R_Red)
# 32               (L_Ale, L_Red)              (R_Ale, R_Red)
# 101                (L_Imperial)                (R_Imperial)
# 102                (L_Imperial)                     (R_Red)
# 105                (L_Imperial)                     (R_Ale)
# 110                (L_Imperial)         (R_Imperial, R_Red)
# 113         (L_Imperial, L_Red)                (R_Imperial)
# 118         (L_Ale, L_Imperial)                (R_Imperial)
# 125                (L_Imperial)         (R_Imperial, R_Ale)
# 127         (L_Imperial, L_Red)                     (R_Red)
# ...
