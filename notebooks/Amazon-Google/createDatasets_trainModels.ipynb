# %%
import sys
sys.path.append("../..")

# %%
import deepmatcher as dm
from utilities_functions.dataset_parser import generate_train_valid_test
import pandas as pd

# %%
train,valid,test = generate_train_valid_test('../../Structured/Amazon-Google','ltable_','rtable_')

# %%
train.to_csv('../../Structured/Amazon-Google/merged_train.csv',index=False)
valid.to_csv('../../Structured/Amazon-Google/merged_valid.csv',index=False)
test.to_csv('../../Structured/Amazon-Google/merged_test.csv',index=False)

# %%
test_pos = test[test['label']==1]
test_pos.to_csv('../../Structured/Amazon-Google/test_positives.csv',index=False)

# %%
test_neg = test[test['label']==0]
test_neg.to_csv('../../Structured/Amazon-Google/test_negatives.csv',index=False)

# %%
allsamples = pd.concat([train,valid,test])
negatives = allsamples[allsamples.label==0]
positives = allsamples[allsamples.label==1]
negatives.to_csv('../../Structured/Amazon-Google/negatives.csv',index=False)
positives.to_csv('../../Structured/Amazon-Google/positives.csv',index=False)

# %%
train,valid,test = dm.data.process('../../Structured/Amazon-Google',train='merged_train.csv',validation='merged_valid.csv',
                                  test='merged_test.csv',left_prefix='ltable_',right_prefix='rtable_')

# %%
hybrid_model = dm.MatchingModel(attr_summarizer='hybrid')
hybrid_model.run_train(train,valid,best_save_path='../../models/amazongoogle_hybrid.pth',epochs=20,pos_neg_ratio=10,batch_size=16)
# Out:
# * Number of trainable parameters: 7133105
# ===>  TRAIN Epoch 1
# Finished Epoch 1 || Run Time:   61.6 | Load Time:    7.1 || F1:  25.79 | Prec:  14.97 | Rec:  92.99 || Ex/s:  99.95
#
# ===>  EVAL Epoch 1
# Finished Epoch 1 || Run Time:    5.7 | Load Time:    1.7 || F1:  42.35 | Prec:  27.09 | Rec:  97.01 || Ex/s: 312.73
#
# * Best F1: 42.35074626865672
# Saving best model...
# Done.
# ---------------------
#
# ===>  TRAIN Epoch 2
# Finished Epoch 2 || Run Time:   60.6 | Load Time:    7.1 || F1:  45.40 | Prec:  29.76 | Rec:  95.71 || Ex/s: 101.44
#
# ===>  EVAL Epoch 2
# Finished Epoch 2 || Run Time:    5.7 | Load Time:    1.7 || F1:  58.22 | Prec:  42.52 | Rec:  92.31 || Ex/s: 310.56
#
# * Best F1: 58.22102425876011
# Saving best model...
# Done.
# ---------------------
#
# ===>  TRAIN Epoch 3
# Finished Epoch 3 || Run Time:   60.5 | Load Time:    7.1 || F1:  59.71 | Prec:  42.96 | Rec:  97.85 || Ex/s: 101.58
#
# ===>  EVAL Epoch 3
# Finished Epoch 3 || Run Time:    5.8 | Load Time:    1.7 || F1:  65.24 | Prec:  53.08 | Rec:  84.62 || Ex/s: 306.36
#
# * Best F1: 65.23887973640856
# Saving best model...
# Done.
# ---------------------
#
# ===>  TRAIN Epoch 4
# Finished Epoch 4 || Run Time:   60.1 | Load Time:    7.0 || F1:  71.15 | Prec:  55.76 | Rec:  98.28 || Ex/s: 102.38
#
# ===>  EVAL Epoch 4
# Finished Epoch 4 || Run Time:    5.8 | Load Time:    1.7 || F1:  64.81 | Prec:  57.19 | Rec:  74.79 || Ex/s: 305.60
#
# ---------------------
#
# ===>  TRAIN Epoch 5
# Finished Epoch 5 || Run Time:   61.2 | Load Time:    7.1 || F1:  78.28 | Prec:  64.73 | Rec:  99.00 || Ex/s: 100.57
#
# ===>  EVAL Epoch 5
# Finished Epoch 5 || Run Time:    6.0 | Load Time:    1.7 || F1:  66.14 | Prec:  52.37 | Rec:  89.74 || Ex/s: 296.96
#
# * Best F1: 66.14173228346458
# Saving best model...
# Done.
# ---------------------
#
# ===>  TRAIN Epoch 6
# Finished Epoch 6 || Run Time:   59.7 | Load Time:    6.9 || F1:  83.48 | Prec:  71.95 | Rec:  99.43 || Ex/s: 103.28
#
# ===>  EVAL Epoch 6
# Finished Epoch 6 || Run Time:    5.8 | Load Time:    1.7 || F1:  66.43 | Prec:  56.21 | Rec:  81.20 || Ex/s: 307.79
#
# * Best F1: 66.43356643356643
# Saving best model...
# Done.
# ---------------------
#
# ===>  TRAIN Epoch 7
# Finished Epoch 7 || Run Time:   62.8 | Load Time:    7.3 || F1:  85.78 | Prec:  75.27 | Rec:  99.71 || Ex/s:  98.05
#
# ===>  EVAL Epoch 7
# Finished Epoch 7 || Run Time:    5.8 | Load Time:    1.7 || F1:  66.18 | Prec:  57.83 | Rec:  77.35 || Ex/s: 305.98
#
# ---------------------
#
# ===>  TRAIN Epoch 8
# Finished Epoch 8 || Run Time:   59.3 | Load Time:    7.0 || F1:  89.53 | Prec:  81.24 | Rec:  99.71 || Ex/s: 103.67
#
# ===>  EVAL Epoch 8
# Finished Epoch 8 || Run Time:    5.6 | Load Time:    1.6 || F1:  67.80 | Prec:  60.88 | Rec:  76.50 || Ex/s: 315.54
#
# * Best F1: 67.8030303030303
# Saving best model...
# Done.
# ---------------------
#
# ===>  TRAIN Epoch 9
# Finished Epoch 9 || Run Time:   60.8 | Load Time:    7.0 || F1:  92.45 | Prec:  86.07 | Rec:  99.86 || Ex/s: 101.37
#
# ===>  EVAL Epoch 9
# Finished Epoch 9 || Run Time:    5.9 | Load Time:    1.7 || F1:  68.36 | Prec:  62.95 | Rec:  74.79 || Ex/s: 301.52
#
# * Best F1: 68.359375
# Saving best model...
# Done.
# ---------------------
#
# ===>  TRAIN Epoch 10
# Finished Epoch 10 || Run Time:   54.9 | Load Time:    6.6 || F1:  93.75 | Prec:  88.35 | Rec:  99.86 || Ex/s: 111.81
#
# ===>  EVAL Epoch 10
# Finished Epoch 10 || Run Time:    5.8 | Load Time:    1.7 || F1:  67.98 | Prec:  62.91 | Rec:  73.93 || Ex/s: 304.79
#
# ---------------------
#
# ===>  TRAIN Epoch 11
# Finished Epoch 11 || Run Time:   61.7 | Load Time:    7.1 || F1:  94.72 | Prec:  89.96 | Rec: 100.00 || Ex/s:  99.92
#
# ===>  EVAL Epoch 11
# Finished Epoch 11 || Run Time:    6.0 | Load Time:    1.7 || F1:  67.46 | Prec:  62.64 | Rec:  73.08 || Ex/s: 298.34
#
# ---------------------
#
# ===>  TRAIN Epoch 12
# Finished Epoch 12 || Run Time:   60.1 | Load Time:    7.1 || F1:  95.43 | Prec:  91.25 | Rec: 100.00 || Ex/s: 102.34
#
# ===>  EVAL Epoch 12
# Finished Epoch 12 || Run Time:    6.0 | Load Time:    1.7 || F1:  67.61 | Prec:  63.88 | Rec:  71.79 || Ex/s: 299.55
#
# ---------------------
#
# ===>  TRAIN Epoch 13
# Finished Epoch 13 || Run Time:   61.3 | Load Time:    7.0 || F1:  95.95 | Prec:  92.22 | Rec: 100.00 || Ex/s: 100.60
#
# ===>  EVAL Epoch 13
# Finished Epoch 13 || Run Time:    5.9 | Load Time:    1.7 || F1:  67.76 | Prec:  65.22 | Rec:  70.51 || Ex/s: 299.47
#
# ---------------------
#
# ===>  TRAIN Epoch 14
# Finished Epoch 14 || Run Time:   61.4 | Load Time:    7.2 || F1:  96.08 | Prec:  92.46 | Rec: 100.00 || Ex/s: 100.15
#
# ===>  EVAL Epoch 14
# Finished Epoch 14 || Run Time:    6.0 | Load Time:    1.7 || F1:  67.63 | Prec:  65.73 | Rec:  69.66 || Ex/s: 298.77
#
# ---------------------
#
# ===>  TRAIN Epoch 15
# Finished Epoch 15 || Run Time:   62.5 | Load Time:    7.3 || F1:  96.28 | Prec:  92.83 | Rec: 100.00 || Ex/s:  98.47
#
# ===>  EVAL Epoch 15
# Finished Epoch 15 || Run Time:    5.8 | Load Time:    1.7 || F1:  67.79 | Prec:  66.80 | Rec:  68.80 || Ex/s: 304.61
#
# ---------------------
#
# ===>  TRAIN Epoch 16
# Finished Epoch 16 || Run Time:   62.0 | Load Time:    7.2 || F1:  96.61 | Prec:  93.45 | Rec: 100.00 || Ex/s:  99.29
#
# ===>  EVAL Epoch 16
# Finished Epoch 16 || Run Time:    5.9 | Load Time:    1.7 || F1:  68.22 | Prec:  67.65 | Rec:  68.80 || Ex/s: 303.15
#
# ---------------------
#
# ===>  TRAIN Epoch 17
# Finished Epoch 17 || Run Time:   54.6 | Load Time:    6.5 || F1:  96.81 | Prec:  93.83 | Rec: 100.00 || Ex/s: 112.33
#
# ===>  EVAL Epoch 17
# Finished Epoch 17 || Run Time:    5.8 | Load Time:    1.7 || F1:  67.80 | Prec:  67.66 | Rec:  67.95 || Ex/s: 305.88
#
# ---------------------
#
# ===>  TRAIN Epoch 18
# Finished Epoch 18 || Run Time:   62.8 | Load Time:    7.3 || F1:  97.29 | Prec:  94.72 | Rec: 100.00 || Ex/s:  98.04
#
# ===>  EVAL Epoch 18
# Finished Epoch 18 || Run Time:    5.7 | Load Time:    1.7 || F1:  67.80 | Prec:  67.66 | Rec:  67.95 || Ex/s: 309.74
#
# ---------------------
#
# ===>  TRAIN Epoch 19
# Finished Epoch 19 || Run Time:   63.4 | Load Time:    7.4 || F1:  97.42 | Prec:  94.97 | Rec: 100.00 || Ex/s:  97.11
#
# ===>  EVAL Epoch 19
# Finished Epoch 19 || Run Time:    6.0 | Load Time:    1.7 || F1:  67.09 | Prec:  67.09 | Rec:  67.09 || Ex/s: 298.73
#
# ---------------------
#
# ===>  TRAIN Epoch 20

# %%
hybrid_model.run_eval(test)
# Out:
# ===>  EVAL Epoch 8
# Finished Epoch 8 || Run Time:    2.8 | Load Time:    1.6 || F1:  68.90 | Prec:  63.87 | Rec:  74.79 || Ex/s: 524.27
# 68.89763779527559

# %%
rnn_model = dm.MatchingModel(attr_summarizer='rnn')
rnn_model.run_train(train,valid,best_save_path='../../models/amazongoogle_rnn.pth',
                    epochs=20,pos_neg_ratio=10)
# Out:
# * Number of trainable parameters: 1762802
# ===>  TRAIN Epoch 1
# Finished Epoch 1 || Run Time:   12.2 | Load Time:    7.9 || F1:  22.98 | Prec:  13.11 | Rec:  93.13 || Ex/s: 341.72
#
# ===>  EVAL Epoch 1
# Finished Epoch 1 || Run Time:    0.9 | Load Time:    1.8 || F1:  26.89 | Prec:  15.67 | Rec:  94.44 || Ex/s: 843.22
#
# * Best F1: 26.885644768856444
# Saving best model...
# Done.
# ---------------------
#
# ===>  TRAIN Epoch 2
# Finished Epoch 2 || Run Time:   12.2 | Load Time:    7.9 || F1:  36.30 | Prec:  22.32 | Rec:  97.14 || Ex/s: 342.34
#
# ===>  EVAL Epoch 2
# Finished Epoch 2 || Run Time:    0.9 | Load Time:    1.7 || F1:  34.05 | Prec:  20.94 | Rec:  91.03 || Ex/s: 877.94
#
# * Best F1: 34.05275779376498
# Saving best model...
# Done.
# ---------------------
#
# ===>  TRAIN Epoch 3
# Finished Epoch 3 || Run Time:   12.4 | Load Time:    8.1 || F1:  53.16 | Prec:  36.32 | Rec:  99.14 || Ex/s: 334.41
#
# ===>  EVAL Epoch 3
# Finished Epoch 3 || Run Time:    0.9 | Load Time:    1.8 || F1:  46.73 | Prec:  33.10 | Rec:  79.49 || Ex/s: 833.09
#
# * Best F1: 46.73366834170854
# Saving best model...
# Done.
# ---------------------
#
# ===>  TRAIN Epoch 4
# Finished Epoch 4 || Run Time:   12.2 | Load Time:    7.8 || F1:  68.45 | Prec:  52.35 | Rec:  98.86 || Ex/s: 343.08
#
# ===>  EVAL Epoch 4
# Finished Epoch 4 || Run Time:    0.9 | Load Time:    1.8 || F1:  50.00 | Prec:  36.65 | Rec:  78.63 || Ex/s: 863.05
#
# * Best F1: 50.00000000000001
# Saving best model...
# Done.
# ---------------------
#
# ===>  TRAIN Epoch 5
# Finished Epoch 5 || Run Time:   12.4 | Load Time:    8.0 || F1:  78.24 | Prec:  64.67 | Rec:  99.00 || Ex/s: 337.93
#
# ===>  EVAL Epoch 5
# Finished Epoch 5 || Run Time:    0.9 | Load Time:    1.7 || F1:  59.32 | Prec:  55.85 | Rec:  63.25 || Ex/s: 876.87
#
# * Best F1: 59.3186372745491
# Saving best model...
# Done.
# ---------------------
#
# ===>  TRAIN Epoch 6
# Finished Epoch 6 || Run Time:   12.4 | Load Time:    8.1 || F1:  83.53 | Prec:  72.02 | Rec:  99.43 || Ex/s: 334.58
#
# ===>  EVAL Epoch 6
# Finished Epoch 6 || Run Time:    0.9 | Load Time:    1.8 || F1:  60.68 | Prec:  56.93 | Rec:  64.96 || Ex/s: 846.42
#
# * Best F1: 60.67864271457085
# Saving best model...
# Done.
# ---------------------
#
# ===>  TRAIN Epoch 7
# Finished Epoch 7 || Run Time:   12.0 | Load Time:    7.7 || F1:  90.33 | Prec:  82.66 | Rec:  99.57 || Ex/s: 348.26
#
# ===>  EVAL Epoch 7
# Finished Epoch 7 || Run Time:    0.8 | Load Time:    1.7 || F1:  59.68 | Prec:  55.51 | Rec:  64.53 || Ex/s: 904.51
#
# ---------------------
#
# ===>  TRAIN Epoch 8
# Finished Epoch 8 || Run Time:   11.1 | Load Time:    7.6 || F1:  92.86 | Prec:  87.00 | Rec:  99.57 || Ex/s: 367.05
#
# ===>  EVAL Epoch 8
# Finished Epoch 8 || Run Time:    0.9 | Load Time:    1.8 || F1:  60.00 | Prec:  55.43 | Rec:  65.38 || Ex/s: 846.18
#
# ---------------------
#
# ===>  TRAIN Epoch 9
# Finished Epoch 9 || Run Time:   11.3 | Load Time:    7.8 || F1:  94.19 | Prec:  89.24 | Rec:  99.71 || Ex/s: 358.81
#
# ===>  EVAL Epoch 9
# Finished Epoch 9 || Run Time:    0.9 | Load Time:    1.8 || F1:  59.88 | Prec:  55.23 | Rec:  65.38 || Ex/s: 845.92
#
# ---------------------
#
# ===>  TRAIN Epoch 10
# Finished Epoch 10 || Run Time:   10.9 | Load Time:    7.7 || F1:  94.84 | Prec:  90.30 | Rec:  99.86 || Ex/s: 369.41
#
# ===>  EVAL Epoch 10
# Finished Epoch 10 || Run Time:    0.9 | Load Time:    1.8 || F1:  60.32 | Prec:  56.30 | Rec:  64.96 || Ex/s: 855.12
#
# ---------------------
#
# ===>  TRAIN Epoch 11
# Finished Epoch 11 || Run Time:   11.1 | Load Time:    7.7 || F1:  96.01 | Prec:  92.45 | Rec:  99.86 || Ex/s: 364.97
#
# ===>  EVAL Epoch 11
# Finished Epoch 11 || Run Time:    0.9 | Load Time:    1.8 || F1:  60.32 | Prec:  56.30 | Rec:  64.96 || Ex/s: 860.23
#
# ---------------------
#
# ===>  TRAIN Epoch 12
# Finished Epoch 12 || Run Time:   11.4 | Load Time:    7.8 || F1:  96.54 | Prec:  93.44 | Rec:  99.86 || Ex/s: 359.61
#
# ===>  EVAL Epoch 12
# Finished Epoch 12 || Run Time:    0.9 | Load Time:    1.7 || F1:  59.88 | Prec:  56.18 | Rec:  64.10 || Ex/s: 890.44
#
# ---------------------
#
# ===>  TRAIN Epoch 13
# Finished Epoch 13 || Run Time:   11.2 | Load Time:    7.7 || F1:  96.88 | Prec:  94.07 | Rec:  99.86 || Ex/s: 363.86
#
# ===>  EVAL Epoch 13
# Finished Epoch 13 || Run Time:    0.8 | Load Time:    1.7 || F1:  60.52 | Prec:  56.98 | Rec:  64.53 || Ex/s: 913.57
#
# ---------------------
#
# ===>  TRAIN Epoch 14
# Finished Epoch 14 || Run Time:   11.2 | Load Time:    7.6 || F1:  97.08 | Prec:  94.45 | Rec:  99.86 || Ex/s: 364.98
#
# ===>  EVAL Epoch 14
# Finished Epoch 14 || Run Time:    0.9 | Load Time:    1.8 || F1:  60.80 | Prec:  57.14 | Rec:  64.96 || Ex/s: 861.14
#
# * Best F1: 60.800000000000004
# Saving best model...
# Done.
# ---------------------
#
# ===>  TRAIN Epoch 15
# Finished Epoch 15 || Run Time:   11.3 | Load Time:    7.9 || F1:  97.15 | Prec:  94.58 | Rec:  99.86 || Ex/s: 357.43
#
# ===>  EVAL Epoch 15
# Finished Epoch 15 || Run Time:    0.9 | Load Time:    1.8 || F1:  60.80 | Prec:  57.14 | Rec:  64.96 || Ex/s: 861.78
#
# ---------------------
#
# ===>  TRAIN Epoch 16
# Finished Epoch 16 || Run Time:   12.0 | Load Time:    8.0 || F1:  97.28 | Prec:  94.84 | Rec:  99.86 || Ex/s: 343.35
#
# ===>  EVAL Epoch 16
# Finished Epoch 16 || Run Time:    0.8 | Load Time:    1.7 || F1:  60.64 | Prec:  57.20 | Rec:  64.53 || Ex/s: 896.60
#
# ---------------------
#
# ===>  TRAIN Epoch 17
# Finished Epoch 17 || Run Time:   12.4 | Load Time:    8.2 || F1:  97.42 | Prec:  95.10 | Rec:  99.86 || Ex/s: 333.92
#
# ===>  EVAL Epoch 17
# Finished Epoch 17 || Run Time:    0.9 | Load Time:    1.8 || F1:  60.52 | Prec:  56.98 | Rec:  64.53 || Ex/s: 860.25
#
# ---------------------
#
# ===>  TRAIN Epoch 18
# Finished Epoch 18 || Run Time:   12.4 | Load Time:    8.2 || F1:  97.49 | Prec:  95.23 | Rec:  99.86 || Ex/s: 334.70
#
# ===>  EVAL Epoch 18
# Finished Epoch 18 || Run Time:    0.9 | Load Time:    1.8 || F1:  60.89 | Prec:  57.63 | Rec:  64.53 || Ex/s: 845.64
#
# * Best F1: 60.88709677419355
# Saving best model...
# Done.
# ---------------------
#
# ===>  TRAIN Epoch 19
# Finished Epoch 19 || Run Time:   11.4 | Load Time:    7.9 || F1:  97.55 | Prec:  95.36 | Rec:  99.86 || Ex/s: 356.58
#
# ===>  EVAL Epoch 19
# Finished Epoch 19 || Run Time:    0.9 | Load Time:    1.8 || F1:  60.73 | Prec:  57.69 | Rec:  64.10 || Ex/s: 845.61
#
# ---------------------
#
# ===>  TRAIN Epoch 20
# Finished Epoch 20 || Run Time:   12.2 | Load Time:    8.0 || F1:  97.55 | Prec:  95.36 | Rec:  99.86 || Ex/s: 339.63
#
# ===>  EVAL Epoch 20
# Finished Epoch 20 || Run Time:    0.9 | Load Time:    1.8 || F1:  60.85 | Prec:  57.92 | Rec:  64.10 || Ex/s: 845.28
#
# ---------------------
#
# Loading best model...
# Training done.
# 60.88709677419355

# %%
rnn_model.run_eval(test)
# Out:
# ===>  EVAL Epoch 18
# Finished Epoch 18 || Run Time:    0.9 | Load Time:    1.8 || F1:  61.73 | Prec:  59.52 | Rec:  64.10 || Ex/s: 851.88
# 61.72839506172839
