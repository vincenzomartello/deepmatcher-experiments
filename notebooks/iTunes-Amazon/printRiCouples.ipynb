# %%
import pandas as pd

# %%
ri_pos_genre = pd.read_csv('experiments-results/exp10/ri_testpos_genre.csv')
ri_pos_genre_sum = ri_pos_genre.sum()

# %%
ri_pos_genre_sum.plot.bar()

# %%
ri_neg_genre = pd.read_csv('experiments-results/exp10/ri_testneg_genre.csv')
ri_neg_genre_sum = ri_neg_genre.sum()

# %%
ri_neg_genre_sum.plot.bar()

# %%
ri_neg_released = pd.read_csv('experiments-results/exp10/ri_testneg_released.csv')
ri_neg_released_sum = ri_neg_released.sum()

# %%
ri_neg_released_sum.plot.bar()

# %%
ri_pos_released = pd.read_csv('experiments-results/exp10/ri_testpos_released.csv')
ri_pos_released_sum = ri_pos_released.sum()

# %%
ri_pos_released_sum.plot.bar()
