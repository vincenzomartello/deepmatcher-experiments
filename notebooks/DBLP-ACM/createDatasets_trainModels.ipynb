# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("../..")

# %%
import deepmatcher as dm
from utilities_functions.dataset_parser import generate_train_valid_test
from deepmatcher.data import MatchingIterator

# %%
train,valid,test = generate_train_valid_test('../../Structured/DBLP-ACM/','ltable_','rtable_')

# %%
train.to_csv('../../Structured/DBLP-ACM/merged_train.csv',index=False)

# %%
dataset = dm.data.process('../../Structured/DBLP-ACM/',train='merged_train.csv',left_prefix='ltable_',
                          right_prefix='rtable_')

# %%
tuple_dataset = dataset,

# %%
splits = MatchingIterator.splits(tuple_dataset,batch_size=32, device = -1)

# %%
for batch in splits[0]:
    print(type(batch))
# Out:
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
# <class 'deepmatcher.batch.MatchingBatch'>
