# %%
import pandas as pd
pos_samples = pd.read_csv('sample_data/itunes-amazon/positives_samples.csv')

# %%
pos_samples.head()
# Out:
#     id  label                      left_Song_Name      left_Artist_Name  \
# 0  287      1                          Outversion           Mark Ronson
# 1  181      1  Stars Come Out ( Tim Mason Remix )                  Zedd
# 2  493      1           Here 's to the Good Times  Florida Georgia Line
# 3  216      1              Jack Daniels and Jesus            Chase Rice
# 4   53      1     I Ai n't Livin ' Long Like This          Chris Janson
#
#                    left_Album_Name  \
# 0                          Version
# 1  Stars Come Out ( Remixes ) - EP
# 2        Here 's to the Good Times
# 3                 Ignite the Night
# 4         Take It to the Bank - EP
#
#                                           left_Genre left_Price  \
# 0  Pop , Music , R&B / Soul,Soul,Dance,Rock,Jazz,...     $ 0.99
# 1                 Dance , Music , Electronic , House     $ 1.29
# 2  Country , Music , Urban Cowboy , Honky Tonk , ...     $ 1.29
# ...

# %%
pos_samples.to_csv('positive_samples_newseparator.csv',sep=';',index=False)

# %%
neg_samples = pd.read_csv('sample_data/itunes-amazon/negative_samples.csv')

# %%
neg_samples.to_csv('negative_samples_newseparator.csv',sep=';',index=False)
